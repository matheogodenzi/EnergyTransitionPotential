# %% [markdown]
# # Covariates choice, preparation, cleaning and analysis

# %% [markdown]
# ### library imports

# %%
# import libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import sys
import os

# Dynamically add the 'utils' folder to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../source/utils')))

# Now, you can import the functions
from utils.municipality_dict import create_municipalities_dict
from utils.merge_covariates import merge_municipalities_covariates
from utils.replace_nan import replace_nan_based_on_type

# %% [markdown]
# ## Pronovo data

# %%
# load cleaned pronovo data 
datapath = "../../data/cleaned_data/Swiss_solar_potential.csv"
Swiss_solar_potential_df = pd.read_csv(datapath, low_memory=False)
Swiss_solar_potential_df.set_index("mun_name", inplace=True)

# %% [markdown]
# ## Covariate data

# %%
# import business creation
business_creation = pd.read_csv("../../data/raw_data/création_entreprises_2021.csv", delimiter=";")
business_creation = business_creation[["GEO_ID", "GEO_NAME", "VALUE"]]
business_creation.columns = ["MunicipalityNumber", "MunicipalityName", "new business"]
business_creation.set_index("MunicipalityName", inplace=True)
business_creation.index
# Out:
# Index(['Aeugst am Albis', 'Affoltern am Albis', 'Bonstetten',
#        'Hausen am Albis', 'Hedingen', 'Kappel am Albis', 'Knonau',
#        'Maschwanden', 'Mettmenstetten', 'Obfelden',
#        ...
#        'Fahy', 'Fontenais', 'Grandfontaine', 'Lugnez', 'Porrentruy',
#        'Vendlincourt', 'Basse-Allaine', 'Clos du Doubs', 'Haute-Ajoie',
#        'La Baroche'],
#       dtype='object', name='MunicipalityName', length=2163)

# %%
# importing share of population in individual households
individual_houselhold_people_share = pd.read_csv("../../data/raw_data/share_of_people_in_individual_households.csv", delimiter=";")
individual_houselhold_people_share=individual_houselhold_people_share[["GEO_ID", "GEO_NAME", "VALUE"]]
individual_houselhold_people_share.columns = ["MunicipalityNumber", "MunicipalityName", "share of people in individual households"]
individual_houselhold_people_share.set_index("MunicipalityName", inplace=True)
individual_houselhold_people_share["share of people in individual households"] = individual_houselhold_people_share["share of people in individual households"]/100
individual_houselhold_people_share
# Out:
#                     MunicipalityNumber  \
# MunicipalityName
# Aeugst am Albis                      1
# Affoltern am Albis                   2
# Bonstetten                           3
# Hausen am Albis                      4
# Hedingen                             5
# ...                                ...
# Basse-Allaine                     6807
# Clos du Doubs                     6808
# Haute-Ajoie                       6809
# La Baroche                        6810
# Damphreux-Lugnez                  6811
#
#                     share of people in individual households
# MunicipalityName
# Aeugst am Albis                                        0.493
# Affoltern am Albis                                     0.209
# Bonstetten                                             0.354
# Hausen am Albis                                        0.474
# Hedingen                                               0.432
# ...                                                      ...
# Basse-Allaine                                          0.702
# Clos du Doubs                                          0.462
# Haute-Ajoie                                            0.643
# La Baroche                                             0.577
# Damphreux-Lugnez                                       0.643
#
# [2136 rows x 2 columns]

# %%
# importing population data 
population_df = pd.read_excel('../../data/raw_data/Municipal_populations_2023.xlsx', skiprows=5, skipfooter=11)
population_df.columns = ["MunicipalityNumber", "MunicipalityName", "Population"]
population_df.set_index("MunicipalityName", inplace=True)
population_df.head()
# Out:
#                     MunicipalityNumber  Population
# MunicipalityName
# Aeugst am Albis                      1        1998
# Affoltern am Albis                   2       12859
# Bonstetten                           3        5678
# Hausen am Albis                      4        3974
# Hedingen                             5        3963

# %%
#importing 9 urbanisation typologies 
urbanization_typo_df = pd.read_excel('../../data/raw_data/Municipalities_typologies_9.xlsx', skiprows=4, skipfooter=11)
urbanization_typo_df.columns = ["MunicipalityNumber", "MunicipalityName", "urban_typo"]
urbanization_typo_df.set_index("MunicipalityName", inplace=True)

#print(urbanization_typo_df["urban_typo"].head(10))
french_cat = [
    'Commune périurbaine de faible densité (23)',
    'Commune urbaine d’une grande agglomération (11)',
    'Commune périurbaine de moyenne densité (22)',
    'Commune périurbaine de forte densité (21)',
    "Commune urbaine d'une agglomération moyenne (12)",
    'Commune urbaine d’une petite ou hors agglomération (13)',
    'Commune rurale en situation centrale (32)',
    'Commune d’un centre rural (31)',
    'Commune rurale périphérique (33)'
]
english_cat = [
    'Low-density peri-urban municipality (23)',
    'Urban municipality in a large agglomeration (11)',
    'Medium-density peri-urban municipality (22)',
    'High-density peri-urban municipality (21)',
    'Urban municipality in a medium-sized agglomeration (12)',
    'Urban municipality in a small or non-agglomerated area (13)',
    'Centrally located rural municipality (32)',
    'Rural center municipality (31)',
    'Peripheral rural municipality (33)'
]

for i, name in enumerate(english_cat):
    urbanization_typo_df["urban_typo"] = urbanization_typo_df["urban_typo"].replace(french_cat[i], name)
    
urbanization_typo_df = urbanization_typo_df.replace('X', 0)

# visualizes df
urbanization_typo_df.tail(10)
# Out:
#                   MunicipalityNumber  \
# MunicipalityName
# Fontenais                       6790
# Grandfontaine                   6792
# Porrentruy                      6800
# Vendlincourt                    6806
# Basse-Allaine                   6807
# Clos du Doubs                   6808
# Haute-Ajoie                     6809
# La Baroche                      6810
# Damphreux-Lugnez                6811
# Basse-Vendline                  6812
#
#                                                          urban_typo
# MunicipalityName
# Fontenais         Urban municipality in a small or non-agglomera...
# Grandfontaine                    Peripheral rural municipality (33)
# Porrentruy        Urban municipality in a small or non-agglomera...
# Vendlincourt                     Peripheral rural municipality (33)
# Basse-Allaine                    Peripheral rural municipality (33)
# Clos du Doubs                    Peripheral rural municipality (33)
# Haute-Ajoie                      Peripheral rural municipality (33)
# La Baroche                       Peripheral rural municipality (33)
# Damphreux-Lugnez                 Peripheral rural municipality (33)
# Basse-Vendline                   Peripheral rural municipality (33)

# %%
#imports mountainous regions
Mountain_region_df = pd.read_excel('../../data/raw_data/régions_de_montagne.xlsx', skiprows=4, skipfooter=11)
Mountain_region_df.columns = ["MunicipalityNumber", "MunicipalityName", "mountain_type"]
Mountain_region_df.set_index("MunicipalityName", inplace=True)
Mountain_region_df.tail()
# Out:
#                              MunicipalityNumber  \
# MunicipalityName
# Lugano: inconnus                        5192999
# Lausanne: inconnus                      5586999
# La Chaux-de-Fonds: inconnus             6421999
# Neuchâtel: inconnus                     6458999
# Genève: inconnus                        6621999
#
#                                                mountain_type
# MunicipalityName
# Lugano: inconnus                                   Alpes (4)
# Lausanne: inconnus           Moyen-pays - Rhin supérieur (1)
# La Chaux-de-Fonds: inconnus                         Jura (3)
# Neuchâtel: inconnus          Moyen-pays - Rhin supérieur (1)
# Genève: inconnus             Moyen-pays - Rhin supérieur (1)

# %%
#imports language repartition
language_df = pd.read_excel('../../data/raw_data/language_repartition.xlsx', skiprows=4, skipfooter=11)
language_df.columns = ["MunicipalityNumber", "MunicipalityName", "language"]
language_df["language"]=language_df["language"].str.replace('Région linguistique ', '', regex=False)
language_df["language"] = language_df["language"].replace("allemande", "german")
language_df["language"] = language_df["language"].replace("italienne", "italian")
language_df["language"] = language_df["language"].replace("française", "french")
language_df["language"] = language_df["language"].replace("romanche", "romansh")

language_df.set_index("MunicipalityName", inplace=True)
language_df.tail()
# Out:
#                   MunicipalityNumber language
# MunicipalityName
# Vendlincourt                    6806   french
# Basse-Allaine                   6807   french
# Clos du Doubs                   6808   french
# Haute-Ajoie                     6809   french
# La Baroche                      6810   french

# %%
#imports votation repartition
votation_df = pd.read_excel('../../data/raw_data/votations_energie.xlsx', skiprows=5, skipfooter=6)
votation_df[["MunicipalityNumber", "MunicipalityName"]] = votation_df[["No commune", "Commune"]]
votation_df.drop( ["No commune","Commune"] , axis=1, inplace=True)
votation_df = votation_df[["MunicipalityName", "MunicipalityNumber", "Canton", "Oui", "Non"]]
votation_df.set_index("MunicipalityName", inplace=True)
votation_df.columns = ["MunicipalityNumber", "Canton", "Yes [nbr]", "No [nbr]"]
votation_df.tail()
# Out:
#                      MunicipalityNumber           Canton  Yes [nbr]  No [nbr]
# MunicipalityName
# AG-Ausland-CH                    9190.0           Aargau       1847       691
# TG-Ausland-CH                    9200.0          Thurgau        856       313
# VD-CH de l'étranger              9220.0             Vaud       4245      1186
# VS-CH de l'étranger              9230.0  Valais / Wallis       1119       325
# GE-CH de l'étranger              9250.0           Genève       5800      1510

# %%
#Municipal stats
Municipal_stats = pd.read_excel('../../data/raw_data/portrait_communes.xlsx', skiprows=5, skipfooter=16)
Municipal_stats.drop([0, 1], axis=0, inplace=True)
Municipal_stats["MunicipalityNumber"] = Municipal_stats["Code commune"]
Municipal_stats["MunicipalityName"] = Municipal_stats["Commune"]
print(Municipal_stats.columns)
Municipal_stats.drop("Code commune", axis=1, inplace=True)
Municipal_stats.drop("Commune", axis=1, inplace=True)
Municipal_stats = Municipal_stats[[
    'MunicipalityName', 
    "MunicipalityNumber",
    "Habitants",
    '0-19 ans', 
    '20-64 ans', 
    '65 ans ou plus',
    'Ménages privés',
    "Surfaces d'habitat et d'infrastructure en %", 
    'Emplois total', 
    'Secteur primaire',
    'Secteur secondaire', 
    'Secteur tertiaire', 
    "Taux d'aide sociale",
    'PLR 2)', 
    'PDC', 
    'PS', 
    'UDC', 
    'PEV/PCS', 
    'PVL',
    'PBD', 
    'PST/Sol.', 
    'PES', 
    'Petits partis de droite'
]]

Municipal_stats.columns = [
    'MunicipalityName',
    'MunicipalityNumber',
    'inhabitants',
    '0-19 years', 
    '20-64 years', 
    '65 years or older',
    'Private households',
    'Housing and infrastructure area (%)',
    'Total employment', 
    'Primary sector',
    'Secondary sector', 
    'Tertiary sector', 
    'Social assistance rate',
    'PLR',  # Swiss political party: FDP.The Liberals
    'PDC',  # Swiss political party: Christian Democratic People's Party
    'PS',   # Swiss political party: Social Democratic Party
    'UDC',  # Swiss political party: Swiss People's Party
    'PEV/PCS',  # Swiss political party: Evangelical People's Party / Christian Social Party
    'PVL',  # Swiss political party: Green Liberal Party
    'PBD',  # Swiss political party: Conservative Democratic Party
    'PST/Sol.',  # Swiss political party: Swiss Labor Party / Solidarity
    'PES',  # Swiss political party: Green Party of Switzerland
    'Small right-wing parties'
]

percentage_cols = [
    '0-19 years', 
    '20-64 years', 
    '65 years or older',
    'Housing and infrastructure area (%)',
    'Social assistance rate',
    'PLR',  # Swiss political party: FDP.The Liberals
    'PDC',  # Swiss political party: Christian Democratic People's Party
    'PS',   # Swiss political party: Social Democratic Party
    'UDC',  # Swiss political party: Swiss People's Party
    'PEV/PCS',  # Swiss political party: Evangelical People's Party / Christian Social Party
    'PVL',  # Swiss political party: Green Liberal Party
    'PBD',  # Swiss political party: Conservative Democratic Party
    'PST/Sol.',  # Swiss political party: Swiss Labor Party / Solidarity
    'PES',  # Swiss political party: Green Party of Switzerland
    'Small right-wing parties'
]

Municipal_stats = Municipal_stats.replace("X", np.nan)
Municipal_stats = Municipal_stats.replace("*", np.nan)
    
for i, col in enumerate(percentage_cols):
    if col == 'Housing and infrastructure area (%)':
        print(i)
        print("before :", Municipal_stats[col])
        Municipal_stats[col] = Municipal_stats[col]*Municipal_stats["inhabitants"]/1000
        print("after:", Municipal_stats[col])
        print("*******************************************\n")
    else:
        print(i)
        print("before :", Municipal_stats[col])
        Municipal_stats[col] = Municipal_stats[col] * Municipal_stats["inhabitants"]/100
        print("after:", Municipal_stats[col])
        print("*******************************************\n")
Municipal_stats["0-64 years"] = Municipal_stats['0-19 years'] + Municipal_stats['20-64 years']
Municipal_stats.drop(columns=['0-19 years', '20-64 years'], inplace=True)
Municipal_stats.set_index("MunicipalityName", inplace=True)
# Out:
# Index(['Code commune', 'Commune', 'Habitants', 'Variation en %',
#        'Densité de la population par km²', 'Etrangers en %', '0-19 ans',
#        '20-64 ans', '65 ans ou plus', 'Taux brut de nuptialité',
#        'Taux brut de divortialité', 'Taux brut de natalité',
#        'Taux brut de mortalité', 'Ménages privés',
#        'Taille moyenne des ménages en personnes', 'Surface totale en km² 1)',
#        'Surfaces d'habitat et d'infrastructure en %', 'Variation en ha',
#        'Surface agricole en %', 'Variation en ha.1', 'Surface boisée en %',
#        'Surface improductive en %', 'Emplois total', 'Secteur primaire',
#        'Secteur secondaire', 'Secteur tertiaire', 'Etablissements total',
#        'Secteur primaire.1', 'Secteur secondaire.1', 'Secteur tertiaire.1',
#        'Taux de logements vacants',
#        'Nouveaux logements construits pour 1000 habitants',
#        'Taux d'aide sociale', 'PLR 2)', 'PDC', 'PS', 'UDC', 'PEV/PCS', 'PVL',
#        'PBD', 'PST/Sol.', 'PES', 'Petits partis de droite',
#        'MunicipalityNumber', 'MunicipalityName'],
#       dtype='object')
# 0
# before : 2       20.000000
# 3       19.787986
# 4       20.165813
# 5       23.636037
# 6       22.180752
#           ...
# 2170    18.425760
# 2171    21.728595
# 2172    18.289786
# 2173    17.788018
# 2174    21.366025
# Name: 0-19 years, Length: 2173, dtype: float64
# after: 2       1721206.6
# 3           392.0
# 4          2481.0
# 5          1317.0
# 6           832.0
#           ...
# 2170        103.0
# 2171        269.0
# 2172        231.0
# 2173        193.0
# 2174        244.0
# Name: 0-19 years, Length: 2173, dtype: float64
# *******************************************
#
# 1
# before : 2       61.400000
# 3       62.190813
# 4       61.667886
# 5       59.834889
# 6       59.824047
#           ...
# 2170    56.887299
# 2171    52.988691
# 2172    56.611243
# 2173    55.483871
# 2174    54.028021
# Name: 20-64 years, Length: 2173, dtype: float64
# after: 2       5284104.262
# 3          1232.000
# 4          7587.000
# 5          3334.000
# 6          2244.000
#            ...
# 2170        318.000
# 2171        656.000
# 2172        715.000
# 2173        602.000
# 2174        617.000
# Name: 20-64 years, Length: 2173, dtype: float64
# *******************************************
#
# 2
# before : 2       18.700000
# 3       18.021201
# 4       18.166301
# 5       16.529074
# 6       17.995201
#           ...
# 2170    24.686941
# 2171    25.282714
# 2172    25.098971
# 2173    26.728111
# 2174    24.605954
# Name: 65 years or older, Length: 2173, dtype: float64
# after: 2       1609328.171
# 3           357.000
# 4          2235.000
# 5           921.000
# 6           675.000
#            ...
# 2170        138.000
# 2171        313.000
# 2172        317.000
# 2173        290.000
# 2174        281.000
# Name: 65 years or older, Length: 2173, dtype: float64
# *******************************************
#
# 3
# before : 2        7.500000
# 3       12.658228
# 4       30.674264
# 5       15.456989
# 6       12.692590
#           ...
# 2170     6.338798
# 2171     7.391304
# 2172     3.626356
# 2173     4.054714
# 2174     4.946996
# Name: Housing and infrastructure area (%), Length: 2173, dtype: float64
# after: 2       64545.247500
# 3          25.075949
# 4         377.385470
# 5          86.126344
# 6          47.609905
#             ...
# 2170        3.543388
# 2171        9.150435
# 2172        4.580087
# 2173        4.399365
# 2174        5.649470
# Name: Housing and infrastructure area (%), Length: 2173, dtype: float64
# *******************************************
#
# 4
# before : 2       3.20
# 3       1.01
# 4       3.02
# 5       1.51
# 6       1.19
#         ...
# 2170    1.67
# 2171    2.11
# 2172    2.10
# 2173    2.37
# 2174    1.46
# Name: Social assistance rate, Length: 2173, dtype: float64
# after: 2       275393.0560
# 3           20.0081
# 4          371.5506
# 5           84.1372
# 6           44.6369
#            ...
# 2170         9.3353
# 2171        26.1218
# 2172        26.5230
# 2173        25.7145
# 2174        16.6732
# Name: Social assistance rate, Length: 2173, dtype: float64
# *******************************************
#
# 5
# before : 2       15.100000
# 3       16.421045
# 4       13.385437
# 5       15.354984
# 6       11.135163
#           ...
# 2170    19.069767
# 2171    13.757962
# 2172     4.482391
# 2173     8.390023
# 2174    13.773796
# Name: PLR, Length: 2173, dtype: float64
# after: 2       1.299511e+06
# 3       3.253009e+02
# 4       1.646810e+03
# 5       8.555797e+02
# 6       4.176800e+02
#             ...
# 2170    1.066000e+02
# 2171    1.703236e+02
# 2172    5.661259e+01
# 2173    9.103175e+01
# 2174    1.572968e+02
# Name: PLR, Length: 2173, dtype: float64
# *******************************************
#
# 6
# before : 2       11.400000
# 3        2.497974
# 4        4.535341
# 5        3.867961
# 6        3.934551
#           ...
# 2170    22.790698
# 2171    40.127389
# 2172    33.297759
# 2173    37.868481
# 2174    27.659574
# Name: PDC, Length: 2173, dtype: float64
# after: 2       981087.762000
# 3           49.484857
# 4          557.983057
# 5          215.522802
# 6          147.585026
#             ...
# 2170       127.400000
# 2171       496.777070
# 2172       420.550694
# 2173       410.873016
# 2174       315.872340
# Name: PDC, Length: 2173, dtype: float64
# *******************************************
#
# 7
# before : 2       16.800000
# 3       11.565102
# 4       14.645255
# 5       16.742891
# 6       13.711509
#           ...
# 2170    17.906977
# 2171    23.566879
# 2172    21.558164
# 2173    19.387755
# 2174    16.349384
# Name: PS, Length: 2173, dtype: float64
# after: 2       1.445814e+06
# 3       2.291047e+02
# 4       1.801806e+03
# 5       9.329139e+02
# 6       5.143187e+02
#             ...
# 2170    1.001000e+02
# 2171    2.917580e+02
# 2172    2.722796e+02
# 2173    2.103571e+02
# 2174    1.867100e+02
# Name: PS, Length: 2173, dtype: float64
# *******************************************
#
# 8
# before : 2       25.600000
# 3       30.380959
# 4       30.306920
# 5       26.116313
# 6       33.184780
#           ...
# 2170    21.162791
# 2171    11.719745
# 2172    14.300961
# 2173    18.707483
# 2174    20.268757
# Name: UDC, Length: 2173, dtype: float64
# after: 2       2.203144e+06
# 3       6.018468e+02
# 4       3.728660e+03
# 5       1.455201e+03
# 6       1.244761e+03
#             ...
# 2170    1.183000e+02
# 2171    1.450904e+02
# 2172    1.806211e+02
# 2173    2.029762e+02
# 2174    2.314692e+02
# Name: UDC, Length: 2173, dtype: float64
# *******************************************
#
# 9
# before : 2        2.400000
# 3        3.227470
# 4        6.618556
# 5        4.194018
# 6        4.059761
#           ...
# 2170     9.767442
# 2171     3.821656
# 2172    10.245464
# 2173     4.195011
# 2174     9.182531
# Name: PEV/PCS, Length: 2173, dtype: float64
# after: 2       206544.792000
# 3           63.936187
# 4          814.280934
# 5          233.690707
# 6          152.281637
#             ...
# 2170        54.600000
# 2171        47.312102
# 2172       129.400213
# 2173        45.515873
# 2174       104.864502
# Name: PEV/PCS, Length: 2173, dtype: float64
# *******************************************
#
# 10
# before : 2        7.800000
# 3       14.317294
# 4       12.666629
# 5       16.237935
# 6       12.416969
#           ...
# 2170          NaN
# 2171          NaN
# 2172          NaN
# 2173          NaN
# 2174          NaN
# Name: PVL, Length: 2173, dtype: float64
# after: 2       671270.574000
# 3          283.625599
# 4         1558.375321
# 5          904.777747
# 6          465.760510
#             ...
# 2170              NaN
# 2171              NaN
# 2172              NaN
# 2173              NaN
# 2174              NaN
# Name: PVL, Length: 2173, dtype: float64
# *******************************************
#
# 11
# before : 2       2.400000
# 3       1.263724
# 4       2.001445
# 5       1.284030
# 6       1.610747
#           ...
# 2170         NaN
# 2171         NaN
# 2172         NaN
# 2173         NaN
# 2174         NaN
# Name: PBD, Length: 2173, dtype: float64
# after: 2       206544.792000
# 3           25.034375
# 4          246.237806
# 5           71.546175
# 6           60.419112
#             ...
# 2170              NaN
# 2171              NaN
# 2172              NaN
# 2173              NaN
# 2174              NaN
# Name: PBD, Length: 2173, dtype: float64
# *******************************************
#
# 12
# before : 2       1.000000
# 3       0.162110
# 4       0.198718
# 5       0.176013
# 6       0.193120
#           ...
# 2170         NaN
# 2171         NaN
# 2172         NaN
# 2173         NaN
# 2174         NaN
# Name: PST/Sol., Length: 2173, dtype: float64
# after: 2       86060.330000
# 3           3.211407
# 4          24.448314
# 5           9.807453
# 6           7.243925
#             ...
# 2170             NaN
# 2171             NaN
# 2172             NaN
# 2173             NaN
# 2174             NaN
# Name: PST/Sol., Length: 2173, dtype: float64
# *******************************************
#
# 13
# before : 2       13.200000
# 3       15.050475
# 4       12.590564
# 5       12.368531
# 6       16.744127
#           ...
# 2170     9.302326
# 2171     7.006369
# 2172    16.115261
# 2173    11.451247
# 2174    12.765957
# Name: PES, Length: 2173, dtype: float64
# after: 2       1.135996e+06
# 3       2.981499e+02
# 4       1.549017e+03
# 5       6.891746e+02
# 6       6.280722e+02
#             ...
# 2170    5.200000e+01
# 2171    8.673885e+01
# 2172    2.035358e+02
# 2173    1.242460e+02
# 2174    1.457872e+02
# Name: PES, Length: 2173, dtype: float64
# *******************************************
#
# 14
# before : 2       2.100000
# 3       3.820647
# 4       1.555518
# 5       1.385022
# 6       1.610747
#           ...
# 2170         NaN
# 2171         NaN
# 2172         NaN
# 2173         NaN
# 2174         NaN
# Name: Small right-wing parties, Length: 2173, dtype: float64
# after: 2       180726.693000
# 3           75.687016
# 4          191.375321
# 5           77.173402
# 6           60.419112
#             ...
# 2170              NaN
# 2171              NaN
# 2172              NaN
# 2173              NaN
# 2174              NaN
# Name: Small right-wing parties, Length: 2173, dtype: float64
# *******************************************
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_4040\2991297646.py:79: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Municipal_stats = Municipal_stats.replace("X", np.nan)
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_4040\2991297646.py:80: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Municipal_stats = Municipal_stats.replace("*", np.nan)

# %%
Municipal_stats.columns
# Out:
# Index(['MunicipalityNumber', 'inhabitants', '65 years or older',
#        'Private households', 'Housing and infrastructure area (%)',
#        'Total employment', 'Primary sector', 'Secondary sector',
#        'Tertiary sector', 'Social assistance rate', 'PLR', 'PDC', 'PS', 'UDC',
#        'PEV/PCS', 'PVL', 'PBD', 'PST/Sol.', 'PES', 'Small right-wing parties',
#        '0-64 years'],
#       dtype='object')

# %%
# load income data
revenue_df =  pd.read_excel('../../data/raw_data/revenu_par_contribuable.xlsx', skiprows=5, skipfooter=12)
revenue_df.columns = ["MunicipalityNumber", "MunicipalityName", "Municipal_rev [CHF]", "revenue_per_capita [CHF]"]
revenue_df["Municipal_rev [CHF]"]*=1000000
revenue_df.set_index("MunicipalityName", inplace=True)

revenue_df = revenue_df.replace("X", np.nan)
revenue_df = revenue_df.replace("*", np.nan)

revenue_df.head()
# Out:
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_4040\3076643527.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   revenue_df = revenue_df.replace("X", np.nan)
#                     MunicipalityNumber  Municipal_rev [CHF]  \
# MunicipalityName
# Aeugst am Albis                      1          109921000.0
# Affoltern am Albis                   2          435719400.0
# Bonstetten                           3          251102000.0
# Hausen am Albis                      4          165486900.0
# Hedingen                             5          177331200.0
#
#                     revenue_per_capita [CHF]
# MunicipalityName
# Aeugst am Albis                          NaN
# Affoltern am Albis              80080.757214
# Bonstetten                      99960.987261
# Hausen am Albis                100968.212325
# Hedingen                       106826.024096

# %%
# load energy consumption data 
energy_cons_df = pd.read_csv("../../data/raw_data/energyreporter_municipality_latest.csv")
print(energy_cons_df.columns)
energy_cons_df = energy_cons_df[["bfs_nr", "municipality", "elec_consumption_households_mwh_per_year_per_capita", "elec_consumption_households_mwh_per_year", "elec_consumption_mwh_per_year_per_capita", "elec_consumption_mwh_per_year"]]
energy_cons_df.columns = ["MunicipalityNumber", "MunicipalityName", "elec_consumption_households_mwh_per_year_per_capita", "elec_consumption_households_mwh_per_year", "elec_consumption_mwh_per_year_per_capita", "elec_consumption_mwh_per_year"]
energy_cons_df.isna().any(axis=1)
energy_cons_df.set_index("MunicipalityName", inplace=True)
energy_cons_df.head()
# Out:
# Index(['bfs_nr', 'municipality', 'canton', 'bfs_municipality_type_2012_25',
#        'electric_car_share', 'electric_car_count',
#        'electric_car_share_last_change', 'electric_car_charging_spot_count',
#        'electric_cars_per_charging_spot',
#        'electric_car_charging_spot_last_change', 'solar_potential_usage',
#        'solar_power_installed_kwp', 'solar_potential_usage_last_change',
#        'renewable_heating_share', 'renewable_heating_count',
#        'non_renewable_heating_count', 'no_heating_count',
#        'renewable_heating_share_coverage',
#        'renewable_heating_share_last_change',
#        'elec_consumption_mwh_per_year_per_capita',
#        'elec_consumption_households_mwh_per_year_per_capita',
#        'elec_consumption_mwh_per_year',
#        'elec_consumption_households_mwh_per_year',
#        'elec_consumption_date_from', 'elec_consumption_date_until',
#        'renelec_production_mwh_per_year_per_capita',
#        'renelec_production_mwh_per_year',
#        'renelec_production_water_mwh_per_year',
#        'renelec_production_solar_mwh_per_year',
#        'renelec_production_wind_mwh_per_year',
#        'renelec_production_biomass_mwh_per_year',
#        'renelec_production_waste_mwh_per_year', 'renelec_production_date_from',
#        'renelec_production_date_until'],
#       dtype='object')
#                     MunicipalityNumber  \
# MunicipalityName
# Aeugst am Albis                      1
# Affoltern am Albis                   2
# Bonstetten                           3
# Hausen am Albis                      4
# Hedingen                             5
#
#                     elec_consumption_households_mwh_per_year_per_capita  \
# MunicipalityName
# Aeugst am Albis                                                2.9119
# Affoltern am Albis                                             1.6492
# Bonstetten                                                     1.7356
# Hausen am Albis                                                2.3004
# Hedingen                                                       2.1157
#
#                     elec_consumption_households_mwh_per_year  \
# MunicipalityName
# Aeugst am Albis                                         5811
# Affoltern am Albis                                     21056
# Bonstetten                                              9827
# Hausen am Albis                                         9128
# Hedingen                                                8335
#
#                     elec_consumption_mwh_per_year_per_capita  \
# MunicipalityName
# Aeugst am Albis                                       4.4623
# Affoltern am Albis                                    4.1840
# Bonstetten                                            2.8006
# Hausen am Albis                                       3.9176
# Hedingen                                              5.3155
#
#                     elec_consumption_mwh_per_year
# MunicipalityName
# Aeugst am Albis                              8905
# Affoltern am Albis                          53420
# Bonstetten                                  15857
# Hausen am Albis                             15545
# Hedingen                                    20941

# %%
# load electricity cost data 
full_elec_cost_df = pd.read_csv("../../data/raw_data/electricity_prices.csv")
operator_prices_df = full_elec_cost_df.groupby(" operatorLabel")[" total (cts./kWh)"].agg(["mean", "std"]).reset_index()
operator_prices_df.columns = ["operatorLabel", "mean_price (cts/kWh)", "std_price (cts/kWh)"]

df_mun = pd.read_csv("../../data/raw_data/electricity_municipality.csv")
print(df_mun.columns)

merged_df = pd.merge(df_mun, operator_prices_df, left_on='operator', right_on='operatorLabel')
elec_cost_df = merged_df.drop(["website", "operatorPostalCode", "operatorLabel", "operatorAddress", "operator", "canton"], axis=1)

print(len(elec_cost_df["municipalityNumber"].unique()))
elec_cost_df = elec_cost_df.drop_duplicates(subset=["municipalityNumber"])
elec_cost_df.columns = ["MunicipalityNumber", "MunicipalityName", "mean_price (cts/kWh)", "std_price (cts/kWh)"]
elec_cost_df.set_index("MunicipalityName", inplace=True)

elec_cost_df.to_csv("../../data/cleaned_data/mun_cost_elec.csv")
elec_cost_df.head()
# Out:
# Index(['operator', 'website', 'municipalityNumber', 'municipalityName',
#        'operatorAddress', 'operatorPostalCode', 'canton'],
#       dtype='object')
# 2079
#                     MunicipalityNumber  mean_price (cts/kWh)  \
# MunicipalityName
# Aeugst am Albis                      1             26.231762
# Affoltern am Albis                   2             26.231762
# Bonstetten                           3             26.231762
# Hausen am Albis                      4             26.231762
# Hedingen                             5             26.231762
#
#                     std_price (cts/kWh)
# MunicipalityName
# Aeugst am Albis                2.464933
# Affoltern am Albis             2.464933
# Bonstetten                     2.464933
# Hausen am Albis                2.464933
# Hedingen                       2.464933

# %%
# load buildings data
buildings_df = pd.read_csv("../../data/raw_data/buildings_2024.csv")
buildings_df.set_index("MunicipalityName", inplace=True)
buildings_df["building_old"] = buildings_df["building_medium_age"] + buildings_df["building_old_age"]
buildings_df.drop(columns=["building_medium_age", "building_old_age"], inplace=True)
buildings_df.head()
# Out:
#                     MunicipalityNumber  building_new_age  building_old
# MunicipalityName
# Aeugst am Albis                      1               998          6628
# Affoltern am Albis                   2              2145         24610
# Bonstetten                           3              1404         13942
# Hausen am Albis                      4              1325         13395
# Hedingen                             5              1219         10773

# %%
# Creates a list of all covariates independent dataframes
covariates_dataframes_list = [population_df, urbanization_typo_df, Mountain_region_df, language_df, votation_df, Municipal_stats, revenue_df, energy_cons_df, elec_cost_df, buildings_df, individual_houselhold_people_share, business_creation]
#list of the dataframe names 
df_names_list = ["Pop_mun_df_2024","urbanization_typo_df", "Mountain_region_df", "language_df", "votation_df", "Municipal_stats", "revenue_df", "energy_cons_df", "elec_cost_df", "buildings_df", "individual_houselhold_people_share", "business_creation"]

# %%
# matching dataframes 
for i, cov_df in enumerate(covariates_dataframes_list):
    print(i)
    #print("Muninicipal_df :", Municipal_df.index)
    #print(f"{df_names_list[i]}:", cov_df.index)

    missing_mun = list(cov_df.index.difference(Swiss_solar_potential_df.index))
    print(f"number of elements that are in {df_names_list[i]} and not in Swiss_solar_potential_df: {len(missing_mun)}")
        
    new_mun = list(Swiss_solar_potential_df.index.difference(cov_df.index))
    print(f"elements in Swiss_solar_potential_df that aren't in {df_names_list[i]}: {len(new_mun)}")
    print("*******************************")
# Out:
# 0
# number of elements that are in Pop_mun_df_2024 and not in Swiss_solar_potential_df: 6
# elements in Swiss_solar_potential_df that aren't in Pop_mun_df_2024: 1
# *******************************
# 1
# number of elements that are in urbanization_typo_df and not in Swiss_solar_potential_df: 0
# elements in Swiss_solar_potential_df that aren't in urbanization_typo_df: 0
# *******************************
# 2
# number of elements that are in Mountain_region_df and not in Swiss_solar_potential_df: 1077
# elements in Swiss_solar_potential_df that aren't in Mountain_region_df: 128
# *******************************
# 3
# number of elements that are in language_df and not in Swiss_solar_potential_df: 19
# elements in Swiss_solar_potential_df that aren't in language_df: 5
# *******************************
# 4
# number of elements that are in votation_df and not in Swiss_solar_potential_df: 19
# elements in Swiss_solar_potential_df that aren't in votation_df: 5
# *******************************
# 5
# number of elements that are in Municipal_stats and not in Swiss_solar_potential_df: 55
# elements in Swiss_solar_potential_df that aren't in Municipal_stats: 13
# *******************************
# 6
# number of elements that are in revenue_df and not in Swiss_solar_potential_df: 115
# elements in Swiss_solar_potential_df that aren't in revenue_df: 24
# *******************************
# 7
# number of elements that are in energy_cons_df and not in Swiss_solar_potential_df: 0
# elements in Swiss_solar_potential_df that aren't in energy_cons_df: 0
# *******************************
# 8
# number of elements that are in elec_cost_df and not in Swiss_solar_potential_df: 4
# elements in Swiss_solar_potential_df that aren't in elec_cost_df: 56
# *******************************
# 9
# number of elements that are in buildings_df and not in Swiss_solar_potential_df: 0
# elements in Swiss_solar_potential_df that aren't in buildings_df: 1
# *******************************
# 10
# number of elements that are in individual_houselhold_people_share and not in Swiss_solar_potential_df: 6
# elements in Swiss_solar_potential_df that aren't in individual_houselhold_people_share: 1
# *******************************
# 11
# number of elements that are in business_creation and not in Swiss_solar_potential_df: 42
# elements in Swiss_solar_potential_df that aren't in business_creation: 10
# *******************************

# %% [markdown]
# ### scrapping a wikipedia page that contains information on Municipalities merges throughout the years

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO  # Import StringIO

# Define the Wikipedia page URL
url = 'https://en.wikipedia.org/wiki/List_of_former_municipalities_of_Switzerland'  # Example URL

# Send a GET request to the page
response = requests.get(url)

# Parse the page content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find the first table on the page (You can also specify which table to scrape)
table = soup.find('table', {'class': 'wikitable'})

# Convert the table HTML to a StringIO object
table_html = str(table)
table_io = StringIO(table_html)

# Use pandas to read the table from the StringIO object
df_wiki = pd.read_html(table_io)[0]

# Display the DataFrame
df_wiki = df_wiki.sort_values(by="Year", ascending=True, inplace=False)
df_wiki = df_wiki[df_wiki.Year >= 2000]
df_wiki.to_csv("../../data/cleaned_data/mun_change.csv", index=False)

#testing
df_wiki[df_wiki.Fate.str.contains('Lugano', case=False, na=False)]
# Out:
#                  Name Canton[3]                      Fate  \
# 303          Cureggia    Ticino  Incorporated into Lugano
# 309   Davesco-Soragno    Ticino  Incorporated into Lugano
# 421           Gandria    Ticino  Incorporated into Lugano
# 909          Pazzallo    Ticino  Incorporated into Lugano
# 140        Breganzona    Ticino  Incorporated into Lugano
# 949        Pregassona    Ticino  Incorporated into Lugano
# 902    Pambio-Noranco    Ticino  Incorporated into Lugano
# 1253        Viganello    Ticino  Incorporated into Lugano
# 1256   Villa Luganese    Ticino  Incorporated into Lugano
# 198          Carabbia    Ticino  Incorporated into Lugano
# 69           Barbengo    Ticino  Incorporated into Lugano
# 1226         Valcolla    Ticino  Incorporated into Lugano
# 201            Carona    Ticino  Incorporated into Lugano
# 185             Cadro    Ticino  Incorporated into Lugano
# 252          Cimadera    Ticino  Incorporated into Lugano
# 1118          Sonvico    Ticino  Incorporated into Lugano
# 119             Bogno    Ticino  Incorporated into Lugano
# 222           Certara    Ticino  Incorporated into Lugano
#
#      Resulting municipality  Year
# 303                  Lugano  2004
# 309                  Lugano  2004
# 421                  Lugano  2004
# 909                  Lugano  2004
# 140                  Lugano  2004
# 949                  Lugano  2004
# 902                  Lugano  2004
# 1253                 Lugano  2004
# 1256                 Lugano  2008
# 198                  Lugano  2008
# 69                   Lugano  2008
# 1226                 Lugano  2013
# 201                  Lugano  2013
# 185                  Lugano  2013
# 252                  Lugano  2013
# 1118                 Lugano  2013
# 119                  Lugano  2013
# 222                  Lugano  2013

# %%
# Get a dictionary of merged municipalities
mun_dict = create_municipalities_dict(df_wiki)
mun_dict["Basse-Vendline"]
# Out:
# ['Bonfol', 'Beurnevésin']

# %%
#getting id's from the new communes

new_muns = list(mun_dict.keys())
mask = Swiss_solar_potential_df.index.str.contains('|'.join(new_muns), case=False, na=False)
new_mun_ids_dict = Swiss_solar_potential_df.loc[mask].mun_id.to_dict()
new_mun_ids_dict["Basse-Vendline"]
# Out:
# 6812

# %%
# creating a list of all dataframes 
all_cleaned_dataframes = []

# %%
Mountain_region_2024_df = merge_municipalities_covariates(Mountain_region_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(Mountain_region_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': ['Cordast', 'Guschelmuth', 'Liebistorf', 'Wallenbuch']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': ['Mannens-Grandsivaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': ['Auressio', 'Berzona', 'Loco']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Avry': ['Avry-sur-Matran', 'Corjolens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Capriasca': ['Bidogno', 'Cagiallo', 'Corticiasca', 'Lopagno', 'Lugaggia', 'Sala Capriasca', 'Tesserete', 'Vaglio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ursy': ['Bionnens', 'Mossel', 'Vauderens', 'Vuarmarens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Villorsonnens': ['Chavannes-sous-Orsonnens', 'Orsonnens', 'Villargiroud', 'Villarsiviriaux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Sâles': ['Maules', 'Romanens', 'Rueyres-Treyfayes']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Hauterive': ['Ecuvillens', 'Posieux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Brillaz': ['Lentigny', 'Lovens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rue': ['Gillarens', 'Promasens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Marsens': ['Vuippens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Suraua': ['Camuns', 'Surcasti', 'Tersnaus', 'Uors-Peiden']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cudrefin': ['Champmartin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Zofingen': ['Mühlethal']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Haut-Intyamon': ['Albeuve', 'Lessoc', 'Montbovon', 'Neirivue']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Vuisternens-devant-Romont': ['Les Ecasseys', 'Estévenens', 'Lieffrens', 'La Magne', 'La Neirigue', 'Sommentier', 'Villariaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Le Mouret': ['Bonnefontaine', 'Montévraz', 'Praroman', 'Zénauva']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Pont-en-Ogoz': ['Avry-devant-Pont', 'Gumefens', 'Le Bry']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Le Glèbe': ['Estavayer-le-Gibloux', 'Rueyres-Saint-Laurent', 'Villarlod', 'Villarsel-le-Gibloux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Courtepin': ['Barberêche', 'Courtaman', 'Villarepos', 'Wallenried']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Riederalp': ['Goppisberg', 'Greich', 'Ried-Mörel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Maracon': ['La Rogivue']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Donat': ['Donath', 'Patzen-Fardün']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bioggio': ['Bosco Luganese', 'Cimo', 'Iseo']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wald': ['Englisberg', 'Zimmerwald']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bas-Intyamon': ['Enney', 'Estavannens', 'Villars-sous-Mont']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ernen': ['Ausserbinn', 'Mühlebach', 'Steinhaus']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wichtrach': ['Niederwichtrach', 'Oberwichtrach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lugano': ['Barbengo', 'Bogno', 'Breganzona', 'Cadro', 'Carabbia', 'Carona', 'Certara', 'Cimadera', 'Cureggia', 'Davesco-Soragno', 'Gandria', 'Pambio-Noranco', 'Pazzallo', 'Pregassona', 'Sonvico', 'Valcolla', 'Viganello', 'Villa Luganese']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mendrisio': ['Arzo', 'Besazio', 'Capolago', 'Genestrerio', 'Ligornetto', 'Meride', 'Rancate', 'Salorino', 'Tremona']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Sonnaz': ['La Corbaz', 'Cormagens', 'Lossy-Formangueires']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Collina d'Oro': ['Agra', 'Carabietta', 'Gentilino', 'Montagnola']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Acquarossa': ['Castro', 'Corzoneso', 'Dongio', 'Largario', 'Leontica', 'Lottigna', 'Marolta', 'Ponto Valentino', 'Prugiasco']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Beromünster': ['Gunzwil', 'Neudorf', 'Schwarzenbach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lavizzara': ['Broglio', 'Brontallo', 'Fusio', 'Menzonio', 'Peccia', 'Prato-Sornico']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Les Montets': ['Aumont', 'Frasses', 'Granges-de-Vesin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Maggia': ['Aurigeno', 'Coglio', 'Giumaglio', 'Lodano', 'Moghegno', 'Someo']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Luchsingen': ['Hätzingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Le Flon': ['Bouloz', 'Porsel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Torny': ['Middes', 'Torny-le-Grand']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Reckingen-Gluringen': ['Gluringen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Münster-Geschinen': ['Geschinen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Verrerie': ['Le Crêt', 'Grattavache', 'Progens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Siviriez': ['Chavannes-les-Forts', 'Prez-vers-Siviriez', 'Villaraboud']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Castel San Pietro': ['Casima', 'Monte']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Thayngen': ['Barzheim', 'Hofen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mézières': ['Berlens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Saint-Martin': ['Besencens', 'Fiaugères']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Alto Malcantone': ['Arosio', 'Breno', 'Fescoggia', 'Mugena', 'Vezio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Nesslau-Krummenau': ['Krummenau', 'Nesslau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Folliaz': ['Villarimboud']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cadenazzo': ['Robasacco']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Delley-Portalban': ['Delley', 'Portalban']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Triengen': ['Kulmerau', 'Wilihof', 'Winikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Surpierre': ['Cheiry', 'Praratoud']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': ['Osterfingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Römerswil': ['Herlisberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cugy': ['Vesin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rovray': ['Arrissoules']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Botterens': ['Villarbeney']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Villarzel': ['Sédeilles']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Faido': ['Anzonico', 'Calonico', 'Calpiogna', 'Campello', 'Cavagnago', 'Chiggiogna', 'Chironico', 'Mairengo', 'Osco', 'Rossura', 'Sobrio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Avenches': ['Donatyre', 'Oleyres']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Haslen': ['Leuggelbach', 'Nidfurn']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ried bei Kerzers': ['Agriswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Blenio': ['Aquila', 'Ghirone', 'Olivone', 'Torre']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Willisau': ['Gettnau', 'Willisau Land', 'Willisau Stadt']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lully': ['Bollion', 'Seiry']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Villigen': ['Stilli']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cevio': ['Bignasco', 'Cavergno']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Vuarmarens': ['Esmonts']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Vernay': ['Autavaux', 'Montbrelloz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Dagmersellen': ['Uffikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ehrendingen': ['Oberehrendingen', 'Unterehrendingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Splügen': ['Medels im Rheinwald']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Erlinsbach': ['Niedererlinsbach', 'Obererlinsbach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bulle': ['La Tour-de-Trême']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Reiden': ['Langnau bei Reiden', 'Richenthal']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ettiswil': ['Kottwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': ['Jona']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Madiswil': ['Gutenburg', 'Kleindietwil', 'Leimiswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Forst-Längenbühl': ['Forst', 'Längenbühl']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Hohenrain': ['Lieli']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'St. Peter-Pagig': ['Pagig', 'St. Peter']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Steg-Hohtenn': ['Hohtenn', 'Steg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Avegno Gordevio': ['Avegno', 'Gordevio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Donneloye': ['Gossens', 'Mézery-près-Donneloye', 'Prahins']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Herzogenbuchsee': ['Oberönz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Trimmis': ['Says']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ferrera': ['Ausserferrera', 'Innerferrera']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val-de-Travers': ['Les Bayards', 'Boveresse', 'Buttes', 'Couvet', 'Fleurier', 'Noiraigue', 'Travers']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Obergoms': ['Obergesteln', 'Oberwald', 'Ulrichen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Tomils': ['Feldis/Veulden', 'Scheid', 'Trans', 'Tumegl/Tomils']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Neckertal': ['Brunnadern', 'Hemberg', 'Oberhelfenschwil', 'St. Peterzell', 'Mogelsberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Clos du Doubs': ['Epauvillers', 'Montenol', 'Montmelon', 'Ocourt', 'Saint-Ursanne', 'Seleute']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val Müstair': ['Fuldera', 'Lü', 'Müstair', 'Tschierv', 'Valchava']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Heimenhausen': ['Röthenbach bei Herzogenbuchsee', 'Wanzwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Baroche': ['Asuel', 'Charmoille', 'Fregiécourt', 'Miécourt', 'Pleujouse']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Anniviers': ['Ayer', 'Chandolin', 'Grimentz', 'Saint-Jean', 'Saint-Luc', 'Vissoie']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': ['Altwis', 'Gelfingen', 'Hämikon', 'Mosen', 'Müswangen', 'Retschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Breggia': ['Bruzella', 'Cabbio', 'Caneggio', 'Morbio Superiore', 'Muggio', 'Sagno']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Riggisberg': ['Rümligen', 'Rüti bei Riggisberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Haute-Ajoie': ['Chevenez', 'Damvant', 'Réclère', "Roche-d'Or", 'Rocourt']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mörel-Filet': ['Filet', 'Mörel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Tène': ['Marin-Epagnier', 'Thielle-Wavre']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Montfaucon': ['Montfavergier']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Basse-Allaine': ['Buix', 'Courtemaîche', 'Montignez']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mundaun': ['Flond', 'Surcuolm']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Andeer': ['Clugin', 'Pignia']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Tschiertschen-Praden': ['Praden', 'Tschiertschen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Centovalli': ['Borgnone', 'Intragna', 'Palagnedra']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Muriaux': ['Le Peuchapatte']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Gampel-Bratsch': ['Bratsch', 'Gampel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Clos-du-Doubs': ['Epiquerez']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Saignelégier': ['Goumois', 'Les Pommerats']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cugnasco-Gerra': ['Cugnasco']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Assens': ['Bioley-Orjulaz', 'Malapalud']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Schaffhausen': ['Hemmental']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cazis': ['Portein', 'Präz', 'Sarn', 'Tartar']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mettauertal': ['Hottwil', 'Etzgen', 'Mettau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Gambarogno': ['Caviano', 'Contone', 'Indemini', 'Magadino', 'Piazzogna', 'San Nazzaro', "Sant'Abbondio"]
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Messen': ['Balm bei Messen', 'Brunnenthal', 'Oberramsern']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Monteceneri': ['Medeglia', 'Bironico', 'Camignolo', 'Rivera', 'Sigirino']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Churwalden': ['Malix', 'Parpan']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Villmergen': ['Hilfikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bregaglia': ['Bondo', 'Castasegna', 'Soglio', 'Stampa', 'Vicosoprano']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': ['Tüscherz-Alfermée', 'Twann']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Brugg': ['Umiken']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Langenthal': ['Obersteckholz', 'Untersteckholz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': ['Ittenthal']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lucerne': ['Littau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Oberdiessbach': ['Bleiken bei Oberdiessbach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wildhaus-Alt St. Johann': ['Alt St. Johann', 'Wildhaus']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Jegenstorf': ['Ballmoos', 'Münchringen', 'Scheunen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Valbroye': ['Combremont-le-Grand', 'Combremont-le-Petit', 'Granges-près-Marnand', 'Marnand', 'Sassel', 'Seigneux', 'Villars-Bramard']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Montilliez': ['Dommartin', 'Naz', 'Poliez-le-Grand', 'Sugnens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bourg-en-Lavaux': ['Cully', 'Epesses', 'Grandvaux', 'Riex']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bettenhausen': ['Bollodingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Vully-les-Lacs': ['Chabrey', 'Constantine', 'Montmagny', 'Vallamand', 'Villars-le-Grand']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mont-Noble': ['Mase', 'Nax', 'Vernamiège']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Glarus Süd': ['Betschwanden', 'Braunwald', 'Elm', 'Engi', 'Haslen', 'Linthal', 'Luchsingen', 'Matt', 'Mitlödi', 'Schwändi', 'Sool']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Aubonne': ['Montherod', 'Pizy']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Glarus Nord': ['Bilten', 'Filzbach', 'Mollis', 'Mühlehorn', 'Näfels', 'Niederurnen', 'Oberurnen', 'Obstalden']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Tévenon': ['Fontanezier', 'Romairon', 'Vaugondry', 'Villars-Burquin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Jorat-Menthue': ['Villars-Tiercelin', 'Montaubion-Chardonney', 'Sottens', 'Villars-Mendraz', 'Peney-le-Jorat']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Goumoëns': ['Goumoens-la-Ville', 'Goumoens-le-Jux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Yverdon-les-Bains': ['Gressy']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lucens': ['Brenles', 'Chesalles-sur-Moudon', 'Cremin', 'Forel-sur-Lucens', 'Oulens-sur-Lucens', 'Sarzens']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Glarus': ['Ennenda', 'Netstal', 'Riedern']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Echichens': ['Monnaz', 'Saint-Saphorin-sur-Morges']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lyss': ['Busswil bei Büren']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Schwarzenburg': ['Albligen', 'Wahlern']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Grüsch': ['Fanas', 'Valzeina']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': ['Villarvolard']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Champvent': ['Essert-sous-Champvent', 'Villars-sous-Champvent']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Oron': ['Bussigny-sur-Oron', 'Châtillens', 'Chesalles-sur-Oron', 'Essertes', 'Oron-la-Ville', 'Oron-le-Châtel', 'Palézieux', 'Les Tavernes', 'Les Thioleyres', 'Vuibroye']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Serravalle': ['Ludiano', 'Malvaglia', 'Semione']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Belp': ['Belpberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Estavayer-le-Lac': ['Font']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Aeschi': ['Steinhof']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Trun': ['Schlans']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Merenschwand': ['Benzenschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Landquart': ['Igis', 'Mastrils']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Servion': ['Les Cullayes']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bözberg': ['Gallenkirch', 'Linn', 'Oberbözberg', 'Unterbözberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lumnezia': ['Cumbel', 'Degen', 'Lumbrein', 'Morissen', 'Vignogn', 'Vella', 'Vrin', 'Suraua']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val-de-Ruz': ['Boudevilliers', 'Cernier', 'Chézard-Saint-Martin', 'Coffrane', 'Dombresson', 'Engollon', 'Fenin-Vilars-Saules', 'Fontainemelon', 'Les Geneveys-sur-Coffrane', 'Les Hauts-Geneveys', 'Montmollin', 'Savagnier', 'Villiers']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Eschenbach': ['Goldingen', 'St. Gallenkappel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Gommiswald': ['Rieden', 'Ernetschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Haute-Sorne': ['Bassecourt', 'Courfaivre', 'Glovelier', 'Soulce', 'Undervelier']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Montanaire': ['Chapelle-sur-Moudon', 'Correvon', 'Denezy', 'Martherenges', 'Neyruz-sur-Moudon', 'Peyres-Possens', 'Saint-Cierges', 'Thierrens', 'Chanéaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Arosa': ['Calfreisen', 'Castiel', 'Langwies', 'Lüen', 'Molinis', 'Peist', 'St. Peter-Pagig']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Sion': ['Les Agettes', 'Salins']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Turtmann-Unterems': ['Turtmann', 'Unterems']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Murten': ['Clavaleyres', 'Büchslen', 'Courlevon', 'Galmiz', 'Gempenach', 'Jeuss', 'Lurtigen', 'Salvenach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Safiental': ['Valendas', 'Versam', 'Safien', 'Tenna']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rapperswil': ['Bangerten', 'Ruppoldsried']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Fontenais': ['Bressaucourt']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wattwil': ['Krinau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Kallnach': ['Niederried bei Kallnach', 'Golaten']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Lüsslingen-Nennigkofen': ['Lüsslingen', 'Nennigkofen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wil': ['Bronschhofen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Leuk': ['Erschmatt']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Escholzmatt-Marbach': ['Escholzmatt']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val Terbi': ['Corban', 'Montsevelier', 'Vermes', 'Vicques']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Naters': ['Birgisch', 'Mund']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bütschwil-Ganterschwil': ['Bütschwil', 'Ganterschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rickenbach': ['Pfeffikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Terre di Pedemonte': ['Cavigliano', 'Tegna', 'Verscio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Beringen': ['Guntmadingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Milvignes': ['Auvernier', 'Bôle']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Drei Höfe': ['Heinrichswil-Winistorf', 'Hersiwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': ['Ohmstal']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Münsingen': ['Tägertschi', 'Trimstein']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Valsot': ['Ramosch', 'Tschlin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Buchegg': ['Aetigkofen', 'Aetingen', 'Brügglen', 'Gossliwil', 'Hessigkofen', 'Küttigkofen', 'Kyburg-Buchegg', 'Lüterswil-Gächliwil', 'Tscheppach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Fraubrunnen': ['Büren zum Hof', 'Etzelkofen', 'Grafenried', 'Limpach', 'Mülchi', 'Schalunen', 'Zauggenried']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Schinznach': ['Oberflachs']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ilanz/Glion': ['Castrisch', 'Ilanz', 'Ladir', 'Luven', 'Pitasch', 'Riein', 'Ruschein', 'Schnaus', 'Sevgein', 'Duvin', 'Pigniu', 'Rueun', 'Siat']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Plateau de Diesse': ['Diesse', 'Lamboing', 'Prêles']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val-de-Charmey': ['Charmey']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Stocken-Höfen': ['Niederstocken', 'Oberstocken']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Sauge': ['Plagne', 'Vauffelin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Uttigen': ['Kienersrüti']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Endingen': ['Unterendingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bremgarten': ['Hermetschwil-Staffeln']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Innertkirchen': ['Gadmen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bettmeralp': ['Betten', 'Martisberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': ['Arvigo', 'Braggio', 'Cauco', 'Selma']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Vals': ['St. Martin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Péry-la-Heutte': ['Péry']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Albula/Alvra': ['Alvaschein', 'Mon', 'Stierva', 'Tiefencastel', 'Alvaneu', 'Brienz/Brinzauls', 'Surava']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Petit-Val': ['Châtelat', 'Monible', 'Sornetan', 'Souboz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Scuol': ['Ardez', 'Guarda', 'Tarasp', 'Ftan', 'Sent']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Valbirse': ['Bévilard', 'Malleray', 'Pontenet']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Domleschg': ['Almens', 'Paspels', 'Pratval', 'Rodels', 'Tomils']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Zernez': ['Lavin', 'Susch']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bauma': ['Sternenberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Surses': ['Bivio', 'Cunter', 'Marmorera', 'Mulegns', 'Riom-Parsonz', 'Salouf', 'Savognin', 'Sur', 'Tinizong-Rona']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Luzein': ['St. Antönien']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Jorat-Mézières': ['Mézières']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Ersigen': ['Niederösch', 'Oberösch']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Onsernone': ['Gresso', 'Mosogno', 'Vergeletto', 'Isorno']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Illnau-Effretikon': ['Kyburg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Gibloux': ['Corpataux-Magnedens', 'Farvagny', 'Vuisternens-en-Ogoz', 'Le Glèbe']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Mont-Vully': ['Bas-Vully', 'Haut-Vully']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Seeberg': ['Hermiswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Obersaxen Mundaun': ['Obersaxen', 'Mundaun']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Belfaux': ['Autafond']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Belmont-Broye': ['Domdidier', 'Léchelles', 'Russy']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rochefort': ['Brot-Dessous']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': ['Estavayer-le-Lac', 'Murist', 'Rueyres-les-Prés', 'Vuissens', 'Vernay']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Goms': ['Blitzingen', 'Niederwald', 'Grafschaft', 'Reckingen-Gluringen', 'Münster-Geschinen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Grono': ['Leggia', 'Verdabbio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bellinzona': ['Camorino', 'Giubiasco', 'Gnosca', 'Gorduno', 'Gudo', 'Moleno', 'Monte Carasso', 'Pianezzo', 'Preonzo', "Sant'Antonio", 'Sementina', 'Claro']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Plaffeien': ['Oberschrot', 'Zumholz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Chavornay': ['Corcelles-sur-Chavornay', 'Essert-Pittet']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Riviera': ['Cresciano', 'Iragna', 'Lodrino', 'Osogna']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Crans-Montana': ['Chermignon', 'Montana', 'Randogne']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Cheyres-Châbles': ['Châbles', 'Cheyres']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Corminboeuf': ['Chésopelloz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bergün Filisur': ['Bergün/Bravuogn', 'Filisur']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Grande Béroche': ['Bevaix', 'Fresens', 'Gorgier', 'Montalchez', 'Saint-Aubin-Sauges', 'Vaumarcus']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Thusis': ['Mutten']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Breil/Brigels': ['Andiast', 'Waltensburg/Vuorz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Kirchdorf': ['Gelterfingen', 'Noflen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Horgen': ['Hirzel']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': ['Scherz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Grosshöchstetten': ['Schlosswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wädenswil': ['Hütten']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Stammheim': ['Oberstammheim', 'Unterstammheim', 'Waltalingen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Reitnau': ['Attelwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Rheinwald': ['Hinterrhein', 'Nufenen', 'Splügen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Courrendlin': ['Rebeuvelier', 'Vellerat']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Prez': ['Corserey', 'Noréaz', 'Prez-vers-Noréaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Verzasca': ['Corippo', 'Frasco', 'Sonogno', 'Vogorno']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Thurnen': ['Kirchenthurnen', 'Lohnstorf', 'Mühlethurnen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Niederbipp': ['Wolfisberg']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Villaz': ['Villaz-Saint-Pierre', 'La Folliaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Steffisburg': ['Schwendibach']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Altishofen': ['Ebersecken']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Chur': ['Maladers', 'Haldenstein']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Seedorf': ['Bauen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Neuchâtel': ['Corcelles-Cormondrèche', 'Peseux', 'Valangin']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val de Bagnes': ['Bagnes', 'Vollèges']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Welschenrohr-Gänsbrunnen': ['Gänsbrunnen', 'Welschenrohr']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Muntogna da Schons': ['Casti-Wergenstein', 'Mathon', 'Donat']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Noble-Contrée': ['Miège', 'Venthône', 'Veyras']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Martigny': ['Charrat']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Tafers': ['Alterswil', 'St. Antoni']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Tresa': ['Croglio', 'Monteggio', 'Ponte Tresa', 'Sessa']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Hautemorges': ['Apples', 'Pampigny', 'Sévery', 'Bussy-Chardonney', 'Reverolle']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Hindelbank': ['Mötschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Le Locle': ['Les Brenets']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Bois-d'Amont': ['Arconciel', 'Senèdes']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': ['Baldingen', 'Böbikon', 'Kaiserstuhl', 'Rietheim', 'Rümikon', 'Wislikofen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Blonay - Saint-Légier': ['Blonay', 'Saint-Légier-La Chiésaz']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Val Mara': ['Maroggia', 'Melano', 'Rovio']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Böztal': ['Bözen', 'Effingen', 'Elfingen', 'Hornussen']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Schwende-Rüte': ['Rüte', 'Schwende']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Münchenbuchsee': ['Diemerswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Damphreux-Lugnez': ['Damphreux', 'Lugnez']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': ['Herznach', 'Ueken']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Les Breuleux': ['La Chaux-des-Breuleux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Andelfingen': ['Humlikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Baden', 'Turgi']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wangen an der Aare': ['Wangen an der Aare', 'Wangenried']
# Numeric sum. Series([], dtype: float64)

# %%
Mountain_region_2024_df.loc["Basse-Vendline"]
# Out:
# MunicipalityNumber                   6812.0
# mountain_type         pas de classification
# Name: Basse-Vendline, dtype: object

# %%
population_2024_df = merge_municipalities_covariates(population_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(population_2024_df)
population_2024_df[population_2024_df.index=="Chur"]
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. Population    3833
# dtype: int64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Population    3833.0
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. Population    363.0
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. Population    767.0
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. Population    3157.0
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. Population    399.0
# dtype: float64
#                   MunicipalityNumber  Population
# MunicipalityName
# Chur                          3901.0     38949.0

# %%
urbanization_typo_2024_df =  merge_municipalities_covariates(urbanization_typo_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(urbanization_typo_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Buchegg': []
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': []
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': []
# Existing rows for target 'Wangen an der Aare': []

# %%
language_df_2024_df =  merge_municipalities_covariates(language_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(language_df_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': ['Hemberg', 'Oberhelfenschwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': ['Diemerswil']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Damphreux-Lugnez': ['Damphreux', 'Lugnez']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': ['Herznach', 'Ueken']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Les Breuleux': ['La Chaux-des-Breuleux']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Andelfingen': ['Humlikon']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. Series([], dtype: float64)
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. Series([], dtype: float64)

# %%
votations_2024_df =  merge_municipalities_covariates(votation_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(votations_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. Yes [nbr]    463
# No [nbr]     689
# dtype: int64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Yes [nbr]    463.0
# No [nbr]     689.0
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. Yes [nbr]    92.0
# No [nbr]     97.0
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. Yes [nbr]     97.0
# No [nbr]     114.0
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. Yes [nbr]    392.0
# No [nbr]     194.0
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. Yes [nbr]    63.0
# No [nbr]     81.0
# dtype: float64

# %%
municipal_stats_2024_df =  merge_municipalities_covariates(Municipal_stats,mun_dict,new_mun_ids_dict, numeric_only=True)
all_cleaned_dataframes.append(municipal_stats_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. inhabitants                            3545.000000
# 65 years or older                       860.000000
# Private households                     1572.000000
# Housing and infrastructure area (%)      11.023105
# Total employment                       1849.000000
# Primary sector                          404.000000
# Secondary sector                        305.000000
# Tertiary sector                        1140.000000
# Social assistance rate                   61.328500
# PLR                                     538.658445
# PDC                                     524.418816
# PS                                      322.171594
# UDC                                    1629.992468
# PEV/PCS                                  71.865625
# PVL                                     131.494069
# PBD                                      10.679721
# PST/Sol.                                  0.000000
# PES                                     252.753405
# Small right-wing parties                 39.603967
# 0-64 years                             2685.000000
# dtype: float64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': ['Hemberg', 'Oberhelfenschwil']
# Numeric sum. inhabitants                            2153.000000
# 65 years or older                       400.000000
# Private households                      845.000000
# Housing and infrastructure area (%)      10.234118
# Total employment                        785.000000
# Primary sector                          234.000000
# Secondary sector                        227.000000
# Tertiary sector                         324.000000
# Social assistance rate                    6.945400
# PLR                                     259.411059
# PDC                                     490.159717
# PS                                      181.121956
# UDC                                     824.579246
# PEV/PCS                                  39.978917
# PVL                                     111.764775
# PBD                                      24.203776
# PST/Sol.                                  0.000000
# PES                                     155.339670
# Small right-wing parties                 57.010388
# 0-64 years                             1753.000000
# dtype: float64
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': ['Bioley-Orjulaz']
# Numeric sum. inhabitants                            520.000000
# 65 years or older                       55.000000
# Private households                     203.000000
# Housing and infrastructure area (%)      5.553398
# Total employment                       836.000000
# Primary sector                          10.000000
# Secondary sector                       417.000000
# Tertiary sector                        409.000000
# Social assistance rate                   8.112000
# PLR                                    182.426230
# PDC                                     35.234973
# PS                                      39.213115
# UDC                                    153.632058
# PEV/PCS                                  4.357013
# PVL                                     24.816029
# PBD                                      2.273224
# PST/Sol.                                15.533698
# PES                                     54.936248
# Small right-wing parties                 1.515483
# 0-64 years                             465.000000
# dtype: float64
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': ['Essertes']
# Numeric sum. inhabitants                            380.000000
# 65 years or older                       57.000000
# Private households                     170.000000
# Housing and infrastructure area (%)      3.662651
# Total employment                        50.000000
# Primary sector                           7.000000
# Secondary sector                        21.000000
# Tertiary sector                         22.000000
# Social assistance rate                   0.000000
# PLR                                     95.497382
# PDC                                      2.652705
# PS                                      73.778360
# UDC                                     94.005236
# PEV/PCS                                  2.155323
# PVL                                     23.874346
# PBD                                      1.160558
# PST/Sol.                                 9.616056
# PES                                     70.959860
# Small right-wing parties                 0.828970
# 0-64 years                             323.000000
# dtype: float64
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': ['Clavaleyres', 'Galmiz', 'Gempenach']
# Numeric sum. inhabitants                            1088.000000
# 65 years or older                       186.000000
# Private households                      480.000000
# Housing and infrastructure area (%)       7.971006
# Total employment                        285.000000
# Primary sector                          178.000000
# Secondary sector                         34.000000
# Tertiary sector                          73.000000
# Social assistance rate                    0.000000
# PLR                                     154.434238
# PDC                                      37.768932
# PS                                      184.157926
# UDC                                     433.863979
# PEV/PCS                                  33.562914
# PVL                                      72.743039
# PBD                                      11.037246
# PST/Sol.                                  0.000000
# PES                                      78.953478
# Small right-wing parties                  9.061236
# 0-64 years                              902.000000
# dtype: float64
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. inhabitants                            3545.000000
# 65 years or older                       860.000000
# Private households                     1572.000000
# Housing and infrastructure area (%)      11.023105
# Total employment                       1849.000000
# Primary sector                          404.000000
# Secondary sector                        305.000000
# Tertiary sector                        1140.000000
# Social assistance rate                   61.328500
# PLR                                     538.658445
# PDC                                     524.418816
# PS                                      322.171594
# UDC                                    1629.992468
# PEV/PCS                                  71.865625
# PVL                                     131.494069
# PBD                                      10.679721
# PST/Sol.                                  0.000000
# PES                                     252.753405
# Small right-wing parties                 39.603967
# 0-64 years                             2685.000000
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. inhabitants                            320.000000
# 65 years or older                       76.000000
# Private households                     143.000000
# Housing and infrastructure area (%)      1.961290
# Total employment                       183.000000
# Primary sector                          19.000000
# Secondary sector                        13.000000
# Tertiary sector                        151.000000
# Social assistance rate                   0.000000
# PLR                                     72.209026
# PDC                                     16.722090
# PS                                      47.885986
# UDC                                    111.733967
# PEV/PCS                                  4.180523
# PVL                                     20.902613
# PBD                                     16.342043
# PST/Sol.                                 0.000000
# PES                                     26.603325
# Small right-wing parties                 1.140143
# 0-64 years                             244.000000
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': ['Croglio', 'Monteggio', 'Ponte Tresa', 'Sessa']
# Numeric sum. inhabitants                            3165.000000
# 65 years or older                       851.000000
# Private households                     1528.000000
# Housing and infrastructure area (%)      82.973105
# Total employment                       2085.000000
# Primary sector                           91.000000
# Secondary sector                       1022.000000
# Tertiary sector                         972.000000
# Social assistance rate                   83.991100
# PLR                                     564.290859
# PDC                                     496.694634
# PS                                      342.681906
# UDC                                     667.088820
# PEV/PCS                                   0.000000
# PVL                                      35.321313
# PBD                                       0.000000
# PST/Sol.                                 35.379151
# PES                                     359.780211
# Small right-wing parties                504.177963
# 0-64 years                             2314.000000
# dtype: float64
# Existing rows for target 'Hautemorges': ['Apples', 'Pampigny', 'Sévery', 'Bussy-Chardonney', 'Reverolle']
# Numeric sum. inhabitants                            3585.000000
# 65 years or older                       574.000000
# Private households                     1426.000000
# Housing and infrastructure area (%)      26.562621
# Total employment                       1076.000000
# Primary sector                          220.000000
# Secondary sector                        211.000000
# Tertiary sector                         645.000000
# Social assistance rate                   53.979800
# PLR                                     877.157015
# PDC                                      78.088196
# PS                                      663.082048
# UDC                                     617.927046
# PEV/PCS                                  36.709967
# PVL                                     282.925886
# PBD                                      13.985948
# PST/Sol.                                 94.164693
# PES                                     832.428927
# Small right-wing parties                  9.046210
# 0-64 years                             3011.000000
# dtype: float64
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': ['Baldingen', 'Böbikon', 'Kaiserstuhl', 'Rietheim', 'Rümikon', 'Wislikofen', 'Bad Zurzach']
# Numeric sum. inhabitants                            6621.000000
# 65 years or older                      1438.000000
# Private households                     2938.000000
# Housing and infrastructure area (%)     156.811638
# Total employment                       3817.000000
# Primary sector                          126.000000
# Secondary sector                        491.000000
# Tertiary sector                        3299.000000
# Social assistance rate                  155.529100
# PLR                                     743.702654
# PDC                                     978.536670
# PS                                     1111.265241
# UDC                                    2207.463575
# PEV/PCS                                  66.832515
# PVL                                     448.112394
# PBD                                     214.861675
# PST/Sol.                                  0.000000
# PES                                     630.649251
# Small right-wing parties                 52.828037
# 0-64 years                             5183.000000
# dtype: float64
# Existing rows for target 'Blonay - Saint-Légier': ['Blonay', 'Saint-Légier-La Chiésaz']
# Numeric sum. inhabitants                            11397.000000
# 65 years or older                       2237.000000
# Private households                      4566.000000
# Housing and infrastructure area (%)      212.059530
# Total employment                        4480.000000
# Primary sector                            83.000000
# Secondary sector                         719.000000
# Tertiary sector                         3678.000000
# Social assistance rate                   173.888400
# PLR                                     3394.478284
# PDC                                      308.949854
# PS                                      2020.011873
# UDC                                     1649.036730
# PEV/PCS                                  153.054774
# PVL                                     1267.705244
# PBD                                       50.262974
# PST/Sol.                                 280.344976
# PES                                     2038.286251
# Small right-wing parties                  36.588449
# 0-64 years                              9160.000000
# dtype: float64
# Existing rows for target 'Val Mara': ['Maroggia', 'Melano', 'Rovio']
# Numeric sum. inhabitants                            2954.000000
# 65 years or older                       593.000000
# Private households                     1347.000000
# Housing and infrastructure area (%)      51.689918
# Total employment                        587.000000
# Primary sector                           19.000000
# Secondary sector                        219.000000
# Tertiary sector                         692.000000
# Social assistance rate                   77.075700
# PLR                                     534.127060
# PDC                                     407.286710
# PS                                      446.303147
# UDC                                     366.407376
# PEV/PCS                                   0.000000
# PVL                                      25.146664
# PBD                                       0.000000
# PST/Sol.                                 21.296539
# PES                                     426.820561
# Small right-wing parties                611.508651
# 0-64 years                             2361.000000
# dtype: float64
# Existing rows for target 'Böztal': ['Bözen', 'Effingen', 'Elfingen', 'Hornussen']
# Numeric sum. inhabitants                            2690.000000
# 65 years or older                       489.000000
# Private households                     1132.000000
# Housing and infrastructure area (%)      26.239132
# Total employment                        633.000000
# Primary sector                          142.000000
# Secondary sector                        107.000000
# Tertiary sector                         384.000000
# Social assistance rate                   33.906300
# PLR                                     190.323081
# PDC                                     305.194871
# PS                                      369.494563
# UDC                                    1190.915563
# PEV/PCS                                  62.453882
# PVL                                     196.780189
# PBD                                      87.949831
# PST/Sol.                                  0.000000
# PES                                     179.802436
# Small right-wing parties                 30.125301
# 0-64 years                             2201.000000
# dtype: float64
# Existing rows for target 'Schwende-Rüte': ['Rüte', 'Schwende']
# Numeric sum. inhabitants                            5876.000000
# 65 years or older                      1015.000000
# Private households                     2224.000000
# Housing and infrastructure area (%)      18.975758
# Total employment                       2385.000000
# Primary sector                          346.000000
# Secondary sector                        642.000000
# Tertiary sector                        1397.000000
# Social assistance rate                    8.954400
# PLR                                       0.000000
# PDC                                    3686.714654
# PS                                      466.868246
# UDC                                    1660.189679
# PEV/PCS                                   0.000000
# PVL                                       0.000000
# PBD                                       0.000000
# PST/Sol.                                  0.000000
# PES                                       0.000000
# Small right-wing parties                  0.000000
# 0-64 years                             4861.000000
# dtype: float64
# Existing rows for target 'Münchenbuchsee': ['Diemerswil']
# Numeric sum. inhabitants                            204.000000
# 65 years or older                       31.000000
# Private households                      73.000000
# Housing and infrastructure area (%)      1.229787
# Total employment                        69.000000
# Primary sector                          40.000000
# Secondary sector                        11.000000
# Tertiary sector                         18.000000
# Social assistance rate                   0.000000
# PLR                                     27.567568
# PDC                                      0.994240
# PS                                      15.727071
# UDC                                     79.629597
# PEV/PCS                                  0.723084
# PVL                                     25.398316
# PBD                                     18.709792
# PST/Sol.                                 1.717324
# PES                                     25.579087
# Small right-wing parties                 2.892335
# 0-64 years                             173.000000
# dtype: float64
# Existing rows for target 'Damphreux-Lugnez': ['Damphreux', 'Lugnez']
# Numeric sum. inhabitants                            361.000000
# 65 years or older                       96.000000
# Private households                     159.000000
# Housing and infrastructure area (%)      2.019091
# Total employment                        51.000000
# Primary sector                          37.000000
# Secondary sector                        22.000000
# Tertiary sector                         28.000000
# Social assistance rate                   0.000000
# PLR                                     56.758065
# PDC                                    112.458065
# PS                                      51.296774
# UDC                                     64.529032
# PEV/PCS                                 29.690323
# PVL                                      0.000000
# PBD                                      0.000000
# PST/Sol.                                 0.000000
# PES                                     46.267742
# Small right-wing parties                 0.000000
# 0-64 years                             265.000000
# dtype: float64
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': ['Herznach', 'Ueken']
# Numeric sum. inhabitants                            2462.000000
# 65 years or older                       374.000000
# Private households                      999.000000
# Housing and infrastructure area (%)      26.396962
# Total employment                        529.000000
# Primary sector                          109.000000
# Secondary sector                        101.000000
# Tertiary sector                         319.000000
# Social assistance rate                   25.563600
# PLR                                     213.235586
# PDC                                     327.044704
# PS                                      210.618068
# UDC                                    1020.876509
# PEV/PCS                                  53.805578
# PVL                                     205.910880
# PBD                                      98.211219
# PST/Sol.                                  0.000000
# PES                                     237.663406
# Small right-wing parties                  7.830135
# 0-64 years                             2088.000000
# dtype: float64
# Existing rows for target 'Les Breuleux': ['La Chaux-des-Breuleux']
# Numeric sum. inhabitants                            99.000000
# 65 years or older                      22.000000
# Private households                     40.000000
# Housing and infrastructure area (%)     0.342222
# Total employment                        0.000000
# Primary sector                         15.000000
# Secondary sector                        0.000000
# Tertiary sector                         6.000000
# Social assistance rate                  0.000000
# PLR                                    11.314286
# PDC                                    29.700000
# PS                                     14.142857
# UDC                                    15.557143
# PEV/PCS                                 9.900000
# PVL                                     0.000000
# PBD                                     0.000000
# PST/Sol.                                0.000000
# PES                                    18.385714
# Small right-wing parties                0.000000
# 0-64 years                             77.000000
# dtype: float64
# Existing rows for target 'Andelfingen': ['Humlikon']
# Numeric sum. inhabitants                            485.000000
# 65 years or older                      101.000000
# Private households                     187.000000
# Housing and infrastructure area (%)      4.612772
# Total employment                       149.000000
# Primary sector                          22.000000
# Secondary sector                        15.000000
# Tertiary sector                        112.000000
# Social assistance rate                   6.984000
# PLR                                     77.338240
# PDC                                     21.788562
# PS                                      32.050751
# UDC                                    234.691812
# PEV/PCS                                 19.557651
# PVL                                     48.633855
# PBD                                      1.933456
# PST/Sol.                                 0.000000
# PES                                     22.532199
# Small right-wing parties                20.673106
# 0-64 years                             384.000000
# dtype: float64
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. inhabitants                            769.000000
# 65 years or older                      249.000000
# Private households                     389.000000
# Housing and infrastructure area (%)      5.099630
# Total employment                       328.000000
# Primary sector                          66.000000
# Secondary sector                       214.000000
# Tertiary sector                         90.000000
# Social assistance rate                  26.406000
# PLR                                     90.048994
# PDC                                    180.083012
# PS                                     155.796962
# UDC                                    221.574882
# PEV/PCS                                 38.578306
# PVL                                      0.000000
# PBD                                      0.000000
# PST/Sol.                                 0.000000
# PES                                     82.917843
# Small right-wing parties                 0.000000
# 0-64 years                             520.000000
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. inhabitants                            3004.000000
# 65 years or older                       441.000000
# Private households                     1380.000000
# Housing and infrastructure area (%)     134.389474
# Total employment                        751.000000
# Primary sector                            0.000000
# Secondary sector                        248.000000
# Tertiary sector                         503.000000
# Social assistance rate                  125.567200
# PLR                                     381.847194
# PDC                                     237.348788
# PS                                      842.617212
# UDC                                     633.123539
# PEV/PCS                                  43.233459
# PVL                                     249.825558
# PBD                                      62.964165
# PST/Sol.                                  0.000000
# PES                                     468.023954
# Small right-wing parties                 15.958659
# 0-64 years                             2563.000000
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. inhabitants                            405.000000
# 65 years or older                       96.000000
# Private households                     175.000000
# Housing and infrastructure area (%)      3.223183
# Total employment                       112.000000
# Primary sector                          34.000000
# Secondary sector                        43.000000
# Tertiary sector                         35.000000
# Social assistance rate                   0.000000
# PLR                                     31.065990
# PDC                                      2.170051
# PS                                      49.796954
# UDC                                    180.571066
# PEV/PCS                                  6.852792
# PVL                                     30.837563
# PBD                                     42.373096
# PST/Sol.                                 0.114213
# PES                                     33.464467
# Small right-wing parties                10.393401
# 0-64 years                             309.000000
# dtype: float64

# %%
revenue_2024_df =  merge_municipalities_covariates(revenue_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(revenue_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. Municipal_rev [CHF]         1.023759e+08
# revenue_per_capita [CHF]    6.454975e+04
# dtype: float64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': ['Cheiry']
# Numeric sum. Municipal_rev [CHF]         9926300.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': ['Gettnau']
# Numeric sum. Municipal_rev [CHF]         26261400.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': ['Hemberg', 'Oberhelfenschwil']
# Numeric sum. Municipal_rev [CHF]         5.654280e+07
# revenue_per_capita [CHF]    6.318977e+04
# dtype: float64
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': ['Altwis']
# Numeric sum. Municipal_rev [CHF]         11188200.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': ['Rümligen']
# Numeric sum. Municipal_rev [CHF]         104126200.0
# revenue_per_capita [CHF]            0.0
# dtype: float64
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': ['Bioley-Orjulaz']
# Numeric sum. Municipal_rev [CHF]         20590600.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': ['Schinznach-Bad']
# Numeric sum. Municipal_rev [CHF]         48805100.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Langenthal': ['Obersteckholz']
# Numeric sum. Municipal_rev [CHF]         12282300.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': ['Montherod']
# Numeric sum. Municipal_rev [CHF]         19180100.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': ['Essertes']
# Numeric sum. Municipal_rev [CHF]         15099000.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': ['Clavaleyres', 'Galmiz', 'Gempenach']
# Numeric sum. Municipal_rev [CHF]         35187300.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': ['Golaten']
# Numeric sum. Municipal_rev [CHF]         1.126870e+07
# revenue_per_capita [CHF]    8.165725e+04
# dtype: float64
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. Municipal_rev [CHF]         1.023759e+08
# revenue_per_capita [CHF]    6.454975e+04
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. Municipal_rev [CHF]         1.159890e+07
# revenue_per_capita [CHF]    7.341076e+04
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': ['Hütten']
# Numeric sum. Municipal_rev [CHF]         33128800.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Stammheim': ['Oberstammheim', 'Unterstammheim', 'Waltalingen']
# Numeric sum. Municipal_rev [CHF]         1.011129e+08
# revenue_per_capita [CHF]    8.189068e+04
# dtype: float64
# Existing rows for target 'Reitnau': ['Attelwil']
# Numeric sum. Municipal_rev [CHF]         9600800.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Rheinwald': ['Hinterrhein', 'Nufenen', 'Splügen']
# Numeric sum. Municipal_rev [CHF]         1.716110e+07
# revenue_per_capita [CHF]    5.455043e+04
# dtype: float64
# Existing rows for target 'Courrendlin': ['Rebeuvelier', 'Vellerat']
# Numeric sum. Municipal_rev [CHF]         13610300.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Prez': ['Corserey', 'Noréaz', 'Prez-vers-Noréaz']
# Numeric sum. Municipal_rev [CHF]         73508300.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Verzasca': ['Corippo', 'Frasco', 'Sonogno', 'Vogorno']
# Numeric sum. Municipal_rev [CHF]         1.353290e+07
# revenue_per_capita [CHF]    1.073234e+05
# dtype: float64
# Existing rows for target 'Thurnen': ['Kirchenthurnen', 'Lohnstorf', 'Mühlethurnen']
# Numeric sum. Municipal_rev [CHF]         6.247010e+07
# revenue_per_capita [CHF]    7.863402e+04
# dtype: float64
# Existing rows for target 'Niederbipp': ['Wolfisberg']
# Numeric sum. Municipal_rev [CHF]         6483700.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Villaz': ['Villaz-Saint-Pierre', 'La Folliaz']
# Numeric sum. Municipal_rev [CHF]         68710000.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Steffisburg': ['Schwendibach']
# Numeric sum. Municipal_rev [CHF]         6.393400e+06
# revenue_per_capita [CHF]    6.801489e+04
# dtype: float64
# Existing rows for target 'Altishofen': ['Ebersecken']
# Numeric sum. Municipal_rev [CHF]         8.993300e+06
# revenue_per_capita [CHF]    6.761880e+04
# dtype: float64
# Existing rows for target 'Chur': ['Maladers', 'Haldenstein']
# Numeric sum. Municipal_rev [CHF]         54043300.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Seedorf': ['Bauen']
# Numeric sum. Municipal_rev [CHF]         6752600.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Neuchâtel': ['Corcelles-Cormondrèche', 'Peseux', 'Valangin']
# Numeric sum. Municipal_rev [CHF]         3.745815e+08
# revenue_per_capita [CHF]    1.680081e+05
# dtype: float64
# Existing rows for target 'Val de Bagnes': ['Bagnes', 'Vollèges']
# Numeric sum. Municipal_rev [CHF]         5.252294e+08
# revenue_per_capita [CHF]    1.485373e+05
# dtype: float64
# Existing rows for target 'Welschenrohr-Gänsbrunnen': ['Gänsbrunnen', 'Welschenrohr']
# Numeric sum. Municipal_rev [CHF]         3.428890e+07
# revenue_per_capita [CHF]    1.259844e+05
# dtype: float64
# Existing rows for target 'Muntogna da Schons': ['Casti-Wergenstein', 'Donat', 'Mathon']
# Numeric sum. Municipal_rev [CHF]         7834200.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Noble-Contrée': ['Miège', 'Venthône', 'Veyras']
# Numeric sum. Municipal_rev [CHF]         1.542202e+08
# revenue_per_capita [CHF]    2.359818e+05
# dtype: float64
# Existing rows for target 'Martigny': ['Charrat']
# Numeric sum. Municipal_rev [CHF]         4.764390e+07
# revenue_per_capita [CHF]    6.719873e+04
# dtype: float64
# Existing rows for target 'Tafers': ['Alterswil', 'St. Antoni']
# Numeric sum. Municipal_rev [CHF]         132814000.0
# revenue_per_capita [CHF]            0.0
# dtype: float64
# Existing rows for target 'Tresa': ['Croglio', 'Monteggio', 'Ponte Tresa', 'Sessa']
# Numeric sum. Municipal_rev [CHF]         9.782730e+07
# revenue_per_capita [CHF]    2.643647e+05
# dtype: float64
# Existing rows for target 'Hautemorges': ['Apples', 'Pampigny', 'Sévery', 'Bussy-Chardonney', 'Reverolle']
# Numeric sum. Municipal_rev [CHF]         1.505777e+08
# revenue_per_capita [CHF]    1.905859e+05
# dtype: float64
# Existing rows for target 'Hindelbank': ['Mötschwil']
# Numeric sum. Municipal_rev [CHF]         4021400.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Le Locle': ['Les Brenets']
# Numeric sum. Municipal_rev [CHF]         4.170410e+07
# revenue_per_capita [CHF]    8.459249e+04
# dtype: float64
# Existing rows for target 'Bois-d'Amont': ['Arconciel', 'Senèdes']
# Numeric sum. Municipal_rev [CHF]         3.802240e+07
# revenue_per_capita [CHF]    6.916094e+04
# dtype: float64
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': ['Baldingen', 'Böbikon', 'Kaiserstuhl', 'Rietheim', 'Rümikon', 'Wislikofen', 'Bad Zurzach']
# Numeric sum. Municipal_rev [CHF]         2.168222e+08
# revenue_per_capita [CHF]    7.327082e+04
# dtype: float64
# Existing rows for target 'Blonay - Saint-Légier': ['Blonay', 'Saint-Légier-La Chiésaz']
# Numeric sum. Municipal_rev [CHF]         5.998658e+08
# revenue_per_capita [CHF]    2.518363e+05
# dtype: float64
# Existing rows for target 'Val Mara': ['Maroggia', 'Melano', 'Rovio']
# Numeric sum. Municipal_rev [CHF]         1.129835e+08
# revenue_per_capita [CHF]    2.498180e+05
# dtype: float64
# Existing rows for target 'Böztal': ['Bözen', 'Effingen', 'Elfingen', 'Hornussen']
# Numeric sum. Municipal_rev [CHF]         9.001580e+07
# revenue_per_capita [CHF]    8.269007e+04
# dtype: float64
# Existing rows for target 'Schwende-Rüte': ['Rüte', 'Schwende']
# Numeric sum. Municipal_rev [CHF]         2.249767e+08
# revenue_per_capita [CHF]    9.293093e+04
# dtype: float64
# Existing rows for target 'Münchenbuchsee': ['Diemerswil']
# Numeric sum. Municipal_rev [CHF]         6855300.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Damphreux-Lugnez': ['Damphreux', 'Lugnez']
# Numeric sum. Municipal_rev [CHF]         9.728400e+06
# revenue_per_capita [CHF]    6.037468e+04
# dtype: float64
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': ['Herznach', 'Ueken']
# Numeric sum. Municipal_rev [CHF]         9.206790e+07
# revenue_per_capita [CHF]    8.465517e+04
# dtype: float64
# Existing rows for target 'Les Breuleux': ['La Chaux-des-Breuleux']
# Numeric sum. Municipal_rev [CHF]         2089700.0
# revenue_per_capita [CHF]          0.0
# dtype: float64
# Existing rows for target 'Andelfingen': ['Humlikon']
# Numeric sum. Municipal_rev [CHF]         20915200.0
# revenue_per_capita [CHF]           0.0
# dtype: float64
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. Municipal_rev [CHF]         2.301450e+07
# revenue_per_capita [CHF]    6.019874e+04
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. Municipal_rev [CHF]         9.770180e+07
# revenue_per_capita [CHF]    7.562059e+04
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. Municipal_rev [CHF]         13644400.0
# revenue_per_capita [CHF]           0.0
# dtype: float64

# %%
energy_cons_2024_df = energy_cons_df.copy()
all_cleaned_dataframes.append(energy_cons_2024_df)

# %%
elec_cost_2024_df = merge_municipalities_covariates(elec_cost_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(elec_cost_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. mean_price (cts/kWh)    28.217101
# std_price (cts/kWh)      3.174948
# dtype: float64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. mean_price (cts/kWh)    28.217101
# std_price (cts/kWh)      3.174948
# dtype: float64
# Existing rows for target 'Buchegg': []
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': []
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': []
# Existing rows for target 'Wangen an der Aare': []

# %%
buildings_2024_df = merge_municipalities_covariates(buildings_df,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(buildings_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. building_new_age     1090
# building_old        20932
# dtype: int64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. building_new_age     1090.0
# building_old        20932.0
# dtype: float64
# Existing rows for target 'Buchegg': []
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': []
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': []
# Existing rows for target 'Wangen an der Aare': []

# %%
individual_houselhold_people_share_2024_df = merge_municipalities_covariates(individual_houselhold_people_share,mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(individual_houselhold_people_share_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. share of people in individual households    0.436
# dtype: float64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': []
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': []
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': []
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. share of people in individual households    0.436
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. share of people in individual households    0.454
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': []
# Existing rows for target 'Blonay - Saint-Légier': []
# Existing rows for target 'Val Mara': []
# Existing rows for target 'Böztal': []
# Existing rows for target 'Schwende-Rüte': []
# Existing rows for target 'Münchenbuchsee': []
# Existing rows for target 'Damphreux-Lugnez': []
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': []
# Existing rows for target 'Les Breuleux': []
# Existing rows for target 'Andelfingen': []
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. share of people in individual households    1.209
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. share of people in individual households    0.231
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. share of people in individual households    0.512
# dtype: float64

# %%
business_creation_2024_df = merge_municipalities_covariates(business_creation, mun_dict,new_mun_ids_dict)
all_cleaned_dataframes.append(business_creation_2024_df)
# Out:
# Existing rows for target 'Guttet-Feschel': []
# Existing rows for target 'Gurmels': []
# Existing rows for target 'Grolley': []
# Existing rows for target 'Grafschaft': []
# Existing rows for target 'Montagny': []
# Existing rows for target 'Diessenhofen': []
# Existing rows for target 'Isorno': []
# Existing rows for target 'Avry': []
# Existing rows for target 'Capriasca': []
# Existing rows for target 'Ursy': []
# Existing rows for target 'Villorsonnens': []
# Existing rows for target 'Sâles': []
# Existing rows for target 'Hauterive': []
# Existing rows for target 'La Brillaz': []
# Existing rows for target 'Rue': []
# Existing rows for target 'Marsens': []
# Existing rows for target 'Suraua': []
# Existing rows for target 'Cudrefin': []
# Existing rows for target 'Zofingen': []
# Existing rows for target 'Haut-Intyamon': []
# Existing rows for target 'Vuisternens-devant-Romont': []
# Existing rows for target 'Le Mouret': []
# Existing rows for target 'Pont-en-Ogoz': []
# Existing rows for target 'Le Glèbe': []
# Existing rows for target 'Courtepin': []
# Existing rows for target 'Riederalp': []
# Existing rows for target 'Maracon': []
# Existing rows for target 'Donat': []
# Existing rows for target 'Bioggio': []
# Existing rows for target 'Wald': []
# Existing rows for target 'Bas-Intyamon': []
# Existing rows for target 'Ernen': []
# Existing rows for target 'Wichtrach': []
# Existing rows for target 'Lugano': []
# Existing rows for target 'Mendrisio': []
# Existing rows for target 'La Sonnaz': []
# Existing rows for target 'Collina d'Oro': []
# Existing rows for target 'Acquarossa': []
# Existing rows for target 'Beromünster': []
# Existing rows for target 'Lavizzara': []
# Existing rows for target 'Les Montets': []
# Existing rows for target 'Maggia': []
# Existing rows for target 'Luchsingen': []
# Existing rows for target 'Le Flon': []
# Existing rows for target 'Torny': []
# Existing rows for target 'Reckingen-Gluringen': []
# Existing rows for target 'Münster-Geschinen': []
# Existing rows for target 'La Verrerie': []
# Existing rows for target 'Siviriez': []
# Existing rows for target 'Castel San Pietro': []
# Existing rows for target 'Thayngen': []
# Existing rows for target 'Mézières': []
# Existing rows for target 'Saint-Martin': []
# Existing rows for target 'Alto Malcantone': []
# Existing rows for target 'Nesslau-Krummenau': ['Nesslau']
# Numeric sum. new business    15.0
# dtype: float64
# Existing rows for target 'La Folliaz': []
# Existing rows for target 'Cadenazzo': []
# Existing rows for target 'Delley-Portalban': []
# Existing rows for target 'Triengen': []
# Existing rows for target 'Surpierre': []
# Existing rows for target 'Cheiry': []
# Existing rows for target 'Wilchingen': []
# Existing rows for target 'Römerswil': []
# Existing rows for target 'Cugy': []
# Existing rows for target 'Rovray': []
# Existing rows for target 'Botterens': []
# Existing rows for target 'Villarzel': []
# Existing rows for target 'Faido': []
# Existing rows for target 'Avenches': []
# Existing rows for target 'Haslen': []
# Existing rows for target 'Ried bei Kerzers': []
# Existing rows for target 'Blenio': []
# Existing rows for target 'Willisau': []
# Existing rows for target 'Lully': []
# Existing rows for target 'Villigen': []
# Existing rows for target 'Cevio': []
# Existing rows for target 'Vuarmarens': []
# Existing rows for target 'Vernay': []
# Existing rows for target 'Dagmersellen': []
# Existing rows for target 'Ehrendingen': []
# Existing rows for target 'Splügen': []
# Existing rows for target 'Erlinsbach': []
# Existing rows for target 'Bulle': []
# Existing rows for target 'Reiden': []
# Existing rows for target 'Ettiswil': []
# Existing rows for target 'St. Antönien': []
# Existing rows for target 'Rapperswil-Jona': []
# Existing rows for target 'Madiswil': []
# Existing rows for target 'Forst-Längenbühl': []
# Existing rows for target 'Hohenrain': []
# Existing rows for target 'St. Peter-Pagig': []
# Existing rows for target 'Steg-Hohtenn': []
# Existing rows for target 'Avegno Gordevio': []
# Existing rows for target 'Donneloye': []
# Existing rows for target 'Herzogenbuchsee': []
# Existing rows for target 'Trimmis': []
# Existing rows for target 'Ferrera': []
# Existing rows for target 'Val-de-Travers': []
# Existing rows for target 'Obergoms': []
# Existing rows for target 'Tomils': []
# Existing rows for target 'Neckertal': ['Hemberg', 'Oberhelfenschwil']
# Numeric sum. new business    8.0
# dtype: float64
# Existing rows for target 'Clos du Doubs': []
# Existing rows for target 'Val Müstair': []
# Existing rows for target 'Heimenhausen': []
# Existing rows for target 'La Baroche': []
# Existing rows for target 'Anniviers': []
# Existing rows for target 'Davos': []
# Existing rows for target 'Hitzkirch': []
# Existing rows for target 'Breggia': []
# Existing rows for target 'Riggisberg': []
# Existing rows for target 'Haute-Ajoie': []
# Existing rows for target 'Mörel-Filet': []
# Existing rows for target 'La Tène': []
# Existing rows for target 'Montfaucon': []
# Existing rows for target 'Basse-Allaine': []
# Existing rows for target 'Mundaun': []
# Existing rows for target 'Andeer': []
# Existing rows for target 'Tschiertschen-Praden': []
# Existing rows for target 'Centovalli': []
# Existing rows for target 'Muriaux': []
# Existing rows for target 'Gampel-Bratsch': []
# Existing rows for target 'Clos-du-Doubs': []
# Existing rows for target 'Saignelégier': []
# Existing rows for target 'Cugnasco-Gerra': []
# Existing rows for target 'Assens': []
# Existing rows for target 'Schaffhausen': []
# Existing rows for target 'Cazis': []
# Existing rows for target 'Mettauertal': []
# Existing rows for target 'Gambarogno': []
# Existing rows for target 'Messen': []
# Existing rows for target 'Monteceneri': []
# Existing rows for target 'Churwalden': []
# Existing rows for target 'Villmergen': []
# Existing rows for target 'Bregaglia': []
# Existing rows for target 'Laufenburg': []
# Existing rows for target 'Twann-Tüscherz': []
# Existing rows for target 'Brugg': []
# Existing rows for target 'Langenthal': []
# Existing rows for target 'Aarau': []
# Existing rows for target 'Kaisten': []
# Existing rows for target 'Lucerne': []
# Existing rows for target 'Oberdiessbach': []
# Existing rows for target 'Wildhaus-Alt St. Johann': []
# Existing rows for target 'Jegenstorf': []
# Existing rows for target 'Valbroye': []
# Existing rows for target 'Montilliez': []
# Existing rows for target 'Bourg-en-Lavaux': []
# Existing rows for target 'Bettenhausen': []
# Existing rows for target 'Vully-les-Lacs': []
# Existing rows for target 'Mont-Noble': []
# Existing rows for target 'Glarus Süd': []
# Existing rows for target 'Aubonne': []
# Existing rows for target 'Glarus Nord': []
# Existing rows for target 'Tévenon': []
# Existing rows for target 'Jorat-Menthue': []
# Existing rows for target 'Goumoëns': []
# Existing rows for target 'Yverdon-les-Bains': []
# Existing rows for target 'Lucens': []
# Existing rows for target 'Glarus': []
# Existing rows for target 'Echichens': []
# Existing rows for target 'Lyss': []
# Existing rows for target 'Schwarzenburg': []
# Existing rows for target 'Grüsch': []
# Existing rows for target 'Riedholz': []
# Existing rows for target 'Corbières': []
# Existing rows for target 'Champvent': []
# Existing rows for target 'Oron': ['Essertes']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Serravalle': []
# Existing rows for target 'Belp': []
# Existing rows for target 'Estavayer-le-Lac': []
# Existing rows for target 'Aeschi': []
# Existing rows for target 'Trun': []
# Existing rows for target 'Merenschwand': []
# Existing rows for target 'Landquart': []
# Existing rows for target 'Servion': []
# Existing rows for target 'Bözberg': []
# Existing rows for target 'Lumnezia': []
# Existing rows for target 'Val-de-Ruz': []
# Existing rows for target 'Eschenbach': []
# Existing rows for target 'Gommiswald': []
# Existing rows for target 'Haute-Sorne': []
# Existing rows for target 'Montanaire': []
# Existing rows for target 'Arosa': []
# Existing rows for target 'Sion': []
# Existing rows for target 'Turtmann-Unterems': []
# Existing rows for target 'Murten': ['Clavaleyres', 'Galmiz', 'Gempenach']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Safiental': []
# Existing rows for target 'Rapperswil': []
# Existing rows for target 'Fontenais': []
# Existing rows for target 'Wattwil': []
# Existing rows for target 'Kallnach': []
# Existing rows for target 'Lüsslingen-Nennigkofen': []
# Existing rows for target 'Wil': []
# Existing rows for target 'Leuk': []
# Existing rows for target 'Escholzmatt-Marbach': []
# Existing rows for target 'Val Terbi': []
# Existing rows for target 'Naters': []
# Existing rows for target 'Bütschwil-Ganterschwil': []
# Existing rows for target 'Rickenbach': []
# Existing rows for target 'Terre di Pedemonte': []
# Existing rows for target 'Beringen': []
# Existing rows for target 'Milvignes': []
# Existing rows for target 'Drei Höfe': []
# Existing rows for target 'Saint-Maurice': []
# Existing rows for target 'Schötz': []
# Existing rows for target 'Münsingen': []
# Existing rows for target 'Valsot': []
# Existing rows for target 'Stein': ['Nesslau-Krummenau']
# Numeric sum. new business    15.0
# dtype: float64
# Existing rows for target 'Buchegg': ['Lüterswil-Gächliwil']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Fraubrunnen': []
# Existing rows for target 'Schinznach': []
# Existing rows for target 'Ilanz/Glion': []
# Existing rows for target 'Plateau de Diesse': []
# Existing rows for target 'Val-de-Charmey': []
# Existing rows for target 'Stocken-Höfen': []
# Existing rows for target 'Sauge': []
# Existing rows for target 'Uttigen': []
# Existing rows for target 'Endingen': []
# Existing rows for target 'Bremgarten': []
# Existing rows for target 'Innertkirchen': []
# Existing rows for target 'Bettmeralp': []
# Existing rows for target 'Wiesendangen': []
# Existing rows for target 'Calanca': []
# Existing rows for target 'Vals': []
# Existing rows for target 'Péry-la-Heutte': []
# Existing rows for target 'Albula/Alvra': []
# Existing rows for target 'Petit-Val': []
# Existing rows for target 'Scuol': []
# Existing rows for target 'Valbirse': []
# Existing rows for target 'Domleschg': []
# Existing rows for target 'Zernez': []
# Existing rows for target 'Bauma': []
# Existing rows for target 'Surses': []
# Existing rows for target 'Luzein': []
# Existing rows for target 'Jorat-Mézières': []
# Existing rows for target 'Ersigen': []
# Existing rows for target 'Onsernone': []
# Existing rows for target 'Illnau-Effretikon': []
# Existing rows for target 'Gibloux': []
# Existing rows for target 'Mont-Vully': []
# Existing rows for target 'Seeberg': []
# Existing rows for target 'Obersaxen Mundaun': []
# Existing rows for target 'Belfaux': []
# Existing rows for target 'Belmont-Broye': []
# Existing rows for target 'Rochefort': []
# Existing rows for target 'Klosters': []
# Existing rows for target 'Estavayer': []
# Existing rows for target 'Goms': []
# Existing rows for target 'Grono': []
# Existing rows for target 'Bellinzona': []
# Existing rows for target 'Plaffeien': []
# Existing rows for target 'Chavornay': []
# Existing rows for target 'Riviera': []
# Existing rows for target 'Crans-Montana': []
# Existing rows for target 'Cheyres-Châbles': []
# Existing rows for target 'Corminboeuf': []
# Existing rows for target 'Bergün Filisur': []
# Existing rows for target 'La Grande Béroche': []
# Existing rows for target 'Thusis': []
# Existing rows for target 'Breil/Brigels': []
# Existing rows for target 'Kirchdorf': []
# Existing rows for target 'Horgen': []
# Existing rows for target 'Elgg': []
# Existing rows for target 'Lupfig': []
# Existing rows for target 'Grosshöchstetten': []
# Existing rows for target 'Wädenswil': []
# Existing rows for target 'Stammheim': []
# Existing rows for target 'Reitnau': []
# Existing rows for target 'Rheinwald': []
# Existing rows for target 'Courrendlin': []
# Existing rows for target 'Prez': []
# Existing rows for target 'Verzasca': []
# Existing rows for target 'Thurnen': []
# Existing rows for target 'Niederbipp': []
# Existing rows for target 'Villaz': []
# Existing rows for target 'Steffisburg': []
# Existing rows for target 'Altishofen': []
# Existing rows for target 'Chur': []
# Existing rows for target 'Seedorf': []
# Existing rows for target 'Neuchâtel': []
# Existing rows for target 'Val de Bagnes': []
# Existing rows for target 'Welschenrohr-Gänsbrunnen': []
# Existing rows for target 'Muntogna da Schons': []
# Existing rows for target 'Noble-Contrée': []
# Existing rows for target 'Martigny': []
# Existing rows for target 'Tafers': []
# Existing rows for target 'Tresa': []
# Existing rows for target 'Hautemorges': []
# Existing rows for target 'Hindelbank': []
# Existing rows for target 'Le Locle': []
# Existing rows for target 'Bois-d'Amont': []
# Existing rows for target 'Stüsslingen': []
# Existing rows for target 'Zurzach': ['Baldingen', 'Böbikon', 'Kaiserstuhl', 'Rietheim', 'Rümikon', 'Wislikofen', 'Bad Zurzach']
# Numeric sum. new business    22.0
# dtype: float64
# Existing rows for target 'Blonay - Saint-Légier': ['Blonay', 'Saint-Légier-La Chiésaz']
# Numeric sum. new business    63.0
# dtype: float64
# Existing rows for target 'Val Mara': ['Maroggia', 'Melano', 'Rovio']
# Numeric sum. new business    21.0
# dtype: float64
# Existing rows for target 'Böztal': ['Bözen', 'Effingen', 'Elfingen', 'Hornussen']
# Numeric sum. new business    5.0
# dtype: float64
# Existing rows for target 'Schwende-Rüte': ['Rüte', 'Schwende']
# Numeric sum. new business    31.0
# dtype: float64
# Existing rows for target 'Münchenbuchsee': ['Diemerswil']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Damphreux-Lugnez': ['Damphreux', 'Lugnez']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Menziken': []
# Existing rows for target 'Herznach-Ueken': ['Herznach', 'Ueken']
# Numeric sum. new business    5.0
# dtype: float64
# Existing rows for target 'Les Breuleux': ['La Chaux-des-Breuleux']
# Numeric sum. new business    0.0
# dtype: float64
# Existing rows for target 'Andelfingen': ['Humlikon']
# Numeric sum. new business    5.0
# dtype: float64
# Existing rows for target 'Basse-Vendline': ['Beurnevésin', 'Bonfol']
# Numeric sum. new business    5.0
# dtype: float64
# Existing rows for target 'Reutigen': []
# Existing rows for target 'Baden': ['Turgi']
# Numeric sum. new business    8.0
# dtype: float64
# Existing rows for target 'Wangen an der Aare': ['Wangenried']
# Numeric sum. new business    0.0
# dtype: float64

# %%
Mountain_region_2024_df[Mountain_region_2024_df.index.str.contains("Basse-Vendline", case=False, na=False)]
# Out:
#                   MunicipalityNumber          mountain_type
# MunicipalityName
# Basse-Vendline                6812.0  pas de classification

# %%
# matching dataframes 
for i, cov_df in enumerate(all_cleaned_dataframes):
    print(i)
    #print("Muninicipal_df :", Municipal_df.index)
    #print(f"{df_names_list[i]}:", cov_df.index)

    missing_mun = list(cov_df.index.difference(Swiss_solar_potential_df.index))
    print(f"number of elements that are in {df_names_list[i]} and not in Swiss_solar_potential_df: {len(missing_mun)}")
        
    new_mun = list(Swiss_solar_potential_df.index.difference(cov_df.index))
    print(f"elements in Swiss_solar_potential_df that aren't in {df_names_list[i]}: {new_mun}")
    print(len(new_mun))
    print("*******************************")
# Out:
# 0
# number of elements that are in Pop_mun_df_2024 and not in Swiss_solar_potential_df: 283
# elements in Swiss_solar_potential_df that aren't in Pop_mun_df_2024: ['Baden', 'Erlinsbach (SO)', 'Hauterive (NE)', 'Nesslau', 'Wald (BE)', 'Wangen an der Aare']
# 6
# *******************************
# 1
# number of elements that are in urbanization_typo_df and not in Swiss_solar_potential_df: 2
# elements in Swiss_solar_potential_df that aren't in urbanization_typo_df: ['Nesslau']
# 1
# *******************************
# 2
# number of elements that are in Mountain_region_df and not in Swiss_solar_potential_df: 1
# elements in Swiss_solar_potential_df that aren't in Mountain_region_df: ['Nesslau']
# 1
# *******************************
# 3
# number of elements that are in language_df and not in Swiss_solar_potential_df: 6
# elements in Swiss_solar_potential_df that aren't in language_df: ['Nesslau']
# 1
# *******************************
# 4
# number of elements that are in votation_df and not in Swiss_solar_potential_df: 15
# elements in Swiss_solar_potential_df that aren't in votation_df: ['Deisswil bei Münchenbuchsee', 'Hellsau', 'Meienried', 'Nesslau', 'Niedermuhlern']
# 5
# *******************************
# 5
# number of elements that are in Municipal_stats and not in Swiss_solar_potential_df: 10
# elements in Swiss_solar_potential_df that aren't in Municipal_stats: ['Lavertezzo', 'Nesslau']
# 2
# *******************************
# 6
# number of elements that are in revenue_df and not in Swiss_solar_potential_df: 15
# elements in Swiss_solar_potential_df that aren't in revenue_df: ['Crans (VD)', 'La Punt Chamues-ch', 'Nesslau']
# 3
# *******************************
# 7
# number of elements that are in energy_cons_df and not in Swiss_solar_potential_df: 0
# elements in Swiss_solar_potential_df that aren't in energy_cons_df: []
# 0
# *******************************
# 8
# number of elements that are in elec_cost_df and not in Swiss_solar_potential_df: 5
# elements in Swiss_solar_potential_df that aren't in elec_cost_df: ['Bargen (BE)', 'Beinwil (Freiamt)', 'Benken (ZH)', 'Bever', 'Buseno', 'Cama', 'Conters im Prättigau', 'Deisswil bei Münchenbuchsee', 'Diessbach bei Büren', 'Disentis/Mustér', 'Falera', 'Fideris', 'Fläsch', 'Furna', 'Geltwil', 'Jenaz', 'Küblis', 'La Punt Chamues-ch', 'Laax', 'Lantsch/Lenz', 'Madulain', 'Malans', 'Melchnau', 'Nesslau', 'Niederried bei Interlaken', 'Pontresina', 'Roggwil (BE)', 'Rottenschwil', 'Rudolfstetten-Friedlisberg', 'Sagogn', 'Schiers', 'Schluein', 'Seewis im Prättigau', 'Sils im Domleschg', 'Silvaplana', 'Sufers', 'Sumvitg', 'Täsch', 'Unterbäch', 'Weiach', 'Wilderswil', 'Zizers', 'Zuoz', 'Zwischbergen']
# 44
# *******************************
# 9
# number of elements that are in buildings_df and not in Swiss_solar_potential_df: 1
# elements in Swiss_solar_potential_df that aren't in buildings_df: ['Nesslau']
# 1
# *******************************
# 10
# number of elements that are in individual_houselhold_people_share and not in Swiss_solar_potential_df: 2
# elements in Swiss_solar_potential_df that aren't in individual_houselhold_people_share: ['Nesslau']
# 1
# *******************************
# 11
# number of elements that are in business_creation and not in Swiss_solar_potential_df: 7
# elements in Swiss_solar_potential_df that aren't in business_creation: ['Nesslau']
# 1
# *******************************

# %% [markdown]
# ages > moyenner les pourcentages par rapport à la population
# ménages privés > somme
# emploi > somme
# logement > moyenne basique
# aide sociale > pondérer par la population
# partis politiques > pondérer par population

# %% [markdown]
# # Merging dataframes

# %%
remaining_df_to_merge = [ 
    population_2024_df, 
    language_df_2024_df, 
    votations_2024_df,
    municipal_stats_2024_df, 
    revenue_2024_df,
    energy_cons_2024_df,
    elec_cost_2024_df, 
    buildings_2024_df,
    individual_houselhold_people_share_2024_df,
    business_creation_2024_df
  ]

urba_final = urbanization_typo_df.reset_index("MunicipalityName")
urba_final = urba_final.set_index("MunicipalityNumber")
urba_final.head()

Mountain_region_final = Mountain_region_2024_df.reset_index("MunicipalityName")
Mountain_region_final = Mountain_region_final.set_index("MunicipalityNumber")
Mountain_region_final = Mountain_region_final.drop("MunicipalityName", axis=1)

Covariates_df = pd.merge(urba_final, Mountain_region_final, left_index=True, right_index=True, how='left')

for df in remaining_df_to_merge:
    df_final = df.reset_index("MunicipalityName")
    df_final = df_final.set_index("MunicipalityNumber")
    df_final = df_final.drop("MunicipalityName", axis=1)

    Covariates_df = pd.merge(Covariates_df, df_final, left_index=True, right_index=True, how='left')

Covariates_final_df=Covariates_df.drop("inhabitants", axis=1)
Covariates_final_df.columns
# Out:
# Index(['MunicipalityName', 'urban_typo', 'mountain_type', 'Population',
#        'language', 'Canton', 'Yes [nbr]', 'No [nbr]', '65 years or older',
#        'Private households', 'Housing and infrastructure area (%)',
#        'Total employment', 'Primary sector', 'Secondary sector',
#        'Tertiary sector', 'Social assistance rate', 'PLR', 'PDC', 'PS', 'UDC',
#        'PEV/PCS', 'PVL', 'PBD', 'PST/Sol.', 'PES', 'Small right-wing parties',
#        '0-64 years', 'Municipal_rev [CHF]', 'revenue_per_capita [CHF]',
#        'elec_consumption_households_mwh_per_year_per_capita',
#        'elec_consumption_households_mwh_per_year',
#        'elec_consumption_mwh_per_year_per_capita',
#        'elec_consumption_mwh_per_year', 'mean_price (cts/kWh)',
#        'std_price (cts/kWh)', 'building_new_age', 'building_old',
#        'share of people in individual households', 'new business'],
#       dtype='object')

# %%
# Check if there are any duplicate indices
duplicate_indices = Covariates_final_df.index[Covariates_final_df.index.duplicated()].tolist()

# Display the rows with duplicate indices
duplicate_rows = Covariates_final_df.loc[Covariates_final_df.index.isin(duplicate_indices)]

# Show the duplicate indices and the corresponding rows
print("Duplicate indices:", duplicate_indices)
#print(duplicate_rows)
print("********************************************\n")

# Drop rows where the index is NaN
Covariates_final_df = Covariates_final_df[Covariates_final_df.index.notna()]

# Drop duplicates but keep the first occurrence
Covariates_final_df = Covariates_final_df.loc[~Covariates_final_df.index.duplicated(keep='first')]

# Verify the result
print("Data after dropping second instance of duplicated indices:")
# Check if there are any duplicate indices
duplicate_indices = Covariates_final_df.index[Covariates_final_df.index.duplicated()].tolist()

# Display the rows with duplicate indices
duplicate_rows = Covariates_final_df.loc[Covariates_final_df.index.isin(duplicate_indices)]

# Show the duplicate indices and the corresponding rows
#print("Duplicate indices:", duplicate_indices)
#print(duplicate_rows)
print("********************************************\n")

Covariates_final_df.shape
# Out:
# Duplicate indices: [2113.0, 2152.0, 2238.0, 2238.0, 2238.0, 3871.0, 3891.0, 3988.0, 3988.0, 3988.0, 5138.0, 5226.0, 5399.0]
# ********************************************
#
# Data after dropping second instance of duplicated indices:
# ********************************************
# (2131, 39)

# %%
# final tests on DF
Swiss_solar_potential_nbr_df = Swiss_solar_potential_df.reset_index()
Swiss_solar_potential_nbr_df = Swiss_solar_potential_nbr_df.set_index("mun_id")
    
missing_mun = list(Covariates_final_df.index.difference(Swiss_solar_potential_nbr_df.index))
print(f"elements that are in Covariates_final_df and not in Swiss_solar_potential_df: {missing_mun}")
    
new_mun = list(Swiss_solar_potential_nbr_df.index.difference(Covariates_final_df.index))
print(f"elements in Swiss_solar_potential_df that aren't in Covariates_final_df: {(new_mun)}")
print("*******************************")
# Out:
# elements that are in Covariates_final_df and not in Swiss_solar_potential_df: []
# elements in Swiss_solar_potential_df that aren't in Covariates_final_df: []
# *******************************

# %% [markdown]
# # FINAL COVARIATE DATAFRAME

# %%
Covariates_final_df.isna().sum()
# Out:
# MunicipalityName                                          0
# urban_typo                                                0
# mountain_type                                             9
# Population                                                1
# language                                                  1
# Canton                                                    5
# Yes [nbr]                                                 5
# No [nbr]                                                  5
# 65 years or older                                         1
# Private households                                        1
# Housing and infrastructure area (%)                       1
# Total employment                                         91
# Primary sector                                           34
# Secondary sector                                         55
# Tertiary sector                                           7
# Social assistance rate                                  460
# PLR                                                      43
# PDC                                                      29
# PS                                                       37
# UDC                                                       9
# PEV/PCS                                                 302
# PVL                                                     117
# PBD                                                     514
# PST/Sol.                                               1152
# PES                                                      67
# Small right-wing parties                                494
# 0-64 years                                                1
# Municipal_rev [CHF]                                       1
# revenue_per_capita [CHF]                                890
# elec_consumption_households_mwh_per_year_per_capita       0
# elec_consumption_households_mwh_per_year                  0
# elec_consumption_mwh_per_year_per_capita                  0
# elec_consumption_mwh_per_year                             0
# mean_price (cts/kWh)                                     53
# std_price (cts/kWh)                                      54
# building_new_age                                          2
# building_old                                              2
# share of people in individual households                  1
# new business                                            542
# dtype: int64

# %%
columns = Covariates_final_df.drop(["PLR", "PDC", "PS", "UDC", "PEV/PCS", "PVL", "PBD", "PST/Sol.", "PES", "Small right-wing parties", "Canton", "Primary sector", "Secondary sector", "Tertiary sector"], axis=1).columns
print(columns)

# Replace NaN values based on column type
updated_df = replace_nan_based_on_type(Covariates_final_df, columns)

print("\nUpdated DataFrame:")
updated_df.head()
# Out:
# Index(['MunicipalityName', 'urban_typo', 'mountain_type', 'Population',
#        'language', 'Yes [nbr]', 'No [nbr]', '65 years or older',
#        'Private households', 'Housing and infrastructure area (%)',
#        'Total employment', 'Social assistance rate', '0-64 years',
#        'Municipal_rev [CHF]', 'revenue_per_capita [CHF]',
#        'elec_consumption_households_mwh_per_year_per_capita',
#        'elec_consumption_households_mwh_per_year',
#        'elec_consumption_mwh_per_year_per_capita',
#        'elec_consumption_mwh_per_year', 'mean_price (cts/kWh)',
#        'std_price (cts/kWh)', 'building_new_age', 'building_old',
#        'share of people in individual households', 'new business'],
#       dtype='object')
# Replaced NaN in numeric column 'Population' with mean: 4193.719248826291
# Replaced NaN in numeric column 'Yes [nbr]' with mean: 634.3786453433678
# Replaced NaN in numeric column 'No [nbr]' with mean: 444.9054562558796
# Replaced NaN in numeric column '65 years or older' with mean: 748.3004694836023
# Replaced NaN in numeric column 'Private households' with mean: 1775.8488262910798
# Replaced NaN in numeric column 'Housing and infrastructure area (%)' with mean: 125.02529096663108
# Replaced NaN in numeric column 'Total employment' with mean: 2517.8745098039217
# Replaced NaN in numeric column 'Social assistance rate' with mean: 167.09400347097548
# Replaced NaN in numeric column '0-64 years' with mean: 3261.7464788733264
# Replaced NaN in numeric column 'Municipal_rev [CHF]' with mean: 149340720.51643193
# Replaced NaN in numeric column 'revenue_per_capita [CHF]' with mean: 83954.3415127094
# Replaced NaN in numeric column 'elec_consumption_households_mwh_per_year_per_capita' with mean: 2.86931928671985
# Replaced NaN in numeric column 'elec_consumption_households_mwh_per_year' with mean: 8278.017832003754
# Replaced NaN in numeric column 'elec_consumption_mwh_per_year_per_capita' with mean: 5.873664382918817
# Replaced NaN in numeric column 'elec_consumption_mwh_per_year' with mean: 23116.847958704835
# Replaced NaN in numeric column 'mean_price (cts/kWh)' with mean: 26.885151130325422
# Replaced NaN in numeric column 'std_price (cts/kWh)' with mean: 4.054072481251712
# Replaced NaN in numeric column 'building_new_age' with mean: 1134.3799906059182
# Replaced NaN in numeric column 'building_old' with mean: 10192.264443400658
# Replaced NaN in numeric column 'share of people in individual households' with mean: 0.3901492957746479
# Replaced NaN in numeric column 'new business' with mean: 26.203272498426685
# Replaced NaN in non-numeric column 'MunicipalityName' with mode: Aadorf
# Replaced NaN in non-numeric column 'urban_typo' with mode: Low-density peri-urban municipality (23)
# Replaced NaN in non-numeric column 'mountain_type' with mode: Moyen-pays - Rhin supérieur (1)
# Replaced NaN in non-numeric column 'language' with mode: german
#
# Updated DataFrame:
#                       MunicipalityName  \
# MunicipalityNumber
# 1.0                    Aeugst am Albis
# 2.0                 Affoltern am Albis
# 3.0                         Bonstetten
# 4.0                    Hausen am Albis
# 5.0                           Hedingen
#
#                                                           urban_typo  \
# MunicipalityNumber
# 1.0                         Low-density peri-urban municipality (23)
# 2.0                 Urban municipality in a large agglomeration (11)
# 3.0                      Medium-density peri-urban municipality (22)
# 4.0                      Medium-density peri-urban municipality (22)
# 5.0                 Urban municipality in a large agglomeration (11)
#
#                                       mountain_type  Population language  \
# MunicipalityNumber
# 1.0                 Moyen-pays - Rhin supérieur (1)      1998.0   german
# 2.0                 Moyen-pays - Rhin supérieur (1)     12859.0   german
# 3.0                 Moyen-pays - Rhin supérieur (1)      5678.0   german
# 4.0                 Moyen-pays - Rhin supérieur (1)      3974.0   german
# 5.0                 Moyen-pays - Rhin supérieur (1)      3963.0   german
#
#                     Canton  Yes [nbr]  No [nbr]  65 years or older  \
# MunicipalityNumber
# 1.0                 Zürich      444.0     335.0              357.0
# 2.0                 Zürich     1884.0    1260.0             2235.0
# 3.0                 Zürich     1197.0     706.0              921.0
# 4.0                 Zürich      764.0     555.0              675.0
# 5.0                 Zürich      809.0     580.0              632.0
#
#                     Private households  ...  \
# MunicipalityNumber                      ...
# 1.0                              848.0  ...
# 2.0                             5412.0  ...
# 3.0                             2327.0  ...
# 4.0                             1552.0  ...
# 5.0                             1580.0  ...
#
#                     elec_consumption_households_mwh_per_year_per_capita  \
# MunicipalityNumber
# 1.0                                                            2.9119
# 2.0                                                            1.6492
# 3.0                                                            1.7356
# 4.0                                                            2.3004
# 5.0                                                            2.1157
#
#                     elec_consumption_households_mwh_per_year  \
# MunicipalityNumber
# 1.0                                                     5811
# 2.0                                                    21056
# 3.0                                                     9827
# 4.0                                                     9128
# 5.0                                                     8335
#
#                     elec_consumption_mwh_per_year_per_capita  \
# MunicipalityNumber
# 1.0                                                   4.4623
# 2.0                                                   4.1840
# 3.0                                                   2.8006
# 4.0                                                   3.9176
# 5.0                                                   5.3155
#
#                     elec_consumption_mwh_per_year  mean_price (cts/kWh)  \
# MunicipalityNumber
# 1.0                                          8905             26.231762
# 2.0                                         53420             26.231762
# 3.0                                         15857             26.231762
# 4.0                                         15545             26.231762
# 5.0                                         20941             26.231762
#
#                     std_price (cts/kWh)  building_new_age  building_old  \
# MunicipalityNumber
# 1.0                            2.464933             998.0        6628.0
# 2.0                            2.464933            2145.0       24610.0
# 3.0                            2.464933            1404.0       13942.0
# 4.0                            2.464933            1325.0       13395.0
# 5.0                            2.464933            1219.0       10773.0
#
#                     share of people in individual households  new business
# MunicipalityNumber
# 1.0                                                    0.493           9.0
# 2.0                                                    0.209          41.0
# 3.0                                                    0.354          21.0
# 4.0                                                    0.474          16.0
# 5.0                                                    0.432          14.0
#
# [5 rows x 39 columns]

# %%
updated_df.isna().sum()
# Out:
# MunicipalityName                                          0
# urban_typo                                                0
# mountain_type                                             0
# Population                                                0
# language                                                  0
# Canton                                                    5
# Yes [nbr]                                                 0
# No [nbr]                                                  0
# 65 years or older                                         0
# Private households                                        0
# Housing and infrastructure area (%)                       0
# Total employment                                          0
# Primary sector                                           34
# Secondary sector                                         55
# Tertiary sector                                           7
# Social assistance rate                                    0
# PLR                                                      43
# PDC                                                      29
# PS                                                       37
# UDC                                                       9
# PEV/PCS                                                 302
# PVL                                                     117
# PBD                                                     514
# PST/Sol.                                               1152
# PES                                                      67
# Small right-wing parties                                494
# 0-64 years                                                0
# Municipal_rev [CHF]                                       0
# revenue_per_capita [CHF]                                  0
# elec_consumption_households_mwh_per_year_per_capita       0
# elec_consumption_households_mwh_per_year                  0
# elec_consumption_mwh_per_year_per_capita                  0
# elec_consumption_mwh_per_year                             0
# mean_price (cts/kWh)                                      0
# std_price (cts/kWh)                                       0
# building_new_age                                          0
# building_old                                              0
# share of people in individual households                  0
# new business                                              0
# dtype: int64

# %%
updated_df.Canton.unique()
# Out:
# array(['Zürich', 'Bern / Berne', nan, 'Luzern', 'Uri', 'Schwyz',
#        'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Fribourg / Freiburg',
#        'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen',
#        'Appenzell Ausserrhoden', 'Appenzell Innerrhoden', 'St. Gallen',
#        'Graubünden / Grigioni / Grischun', 'Aargau', 'Thurgau', 'Ticino',
#        'Vaud', 'Valais / Wallis', 'Neuchâtel', 'Genève', 'Jura'],
#       dtype=object)

# %%
updated_df.loc[updated_df["Canton"].isna(), "Canton"] = ["Bern / Berne", "Bern / Berne", "Bern / Berne", "Bern / Berne", "St. Gallen"]

# %%
mun_check = ["Meienried", "Hellsau", "Deisswil bei Münchenbuchsee", "Niedermuhlern", "Nesslau"]
updated_df[updated_df.MunicipalityName.isin(mun_check)]["Canton"]
# Out:
# MunicipalityNumber
# 389.0     Bern / Berne
# 408.0     Bern / Berne
# 535.0     Bern / Berne
# 877.0     Bern / Berne
# 3360.0      St. Gallen
# Name: Canton, dtype: object

# %%
Covariates_final_df.columns
# Out:
# Index(['MunicipalityName', 'urban_typo', 'mountain_type', 'Population',
#        'language', 'Canton', 'Yes [nbr]', 'No [nbr]', '65 years or older',
#        'Private households', 'Housing and infrastructure area (%)',
#        'Total employment', 'Primary sector', 'Secondary sector',
#        'Tertiary sector', 'Social assistance rate', 'PLR', 'PDC', 'PS', 'UDC',
#        'PEV/PCS', 'PVL', 'PBD', 'PST/Sol.', 'PES', 'Small right-wing parties',
#        '0-64 years', 'Municipal_rev [CHF]', 'revenue_per_capita [CHF]',
#        'elec_consumption_households_mwh_per_year_per_capita',
#        'elec_consumption_households_mwh_per_year',
#        'elec_consumption_mwh_per_year_per_capita',
#        'elec_consumption_mwh_per_year', 'mean_price (cts/kWh)',
#        'std_price (cts/kWh)', 'building_new_age', 'building_old',
#        'share of people in individual households', 'new business'],
#       dtype='object')

# %%
Covariates_final_df.reset_index()
Covariates_final_df.to_csv("../../data/cleaned_data/Covariates.csv", index=True, encoding='utf-8')
