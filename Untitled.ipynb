# %% [markdown]
# # Energy consumption Switzerland

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn as sk
import numpy as np

# %%
df = pd.read_csv("../Statistical_data/energyreporter_municipality_latest.csv")

# %%
df.head()
# Out:
#    bfs_nr        municipality canton  bfs_municipality_type_2012_25  \
# 0       1     Aeugst am Albis     ZH                            237
# 1       2  Affoltern am Albis     ZH                            112
# 2       3          Bonstetten     ZH                            227
# 3       4     Hausen am Albis     ZH                            227
# 4       5            Hedingen     ZH                            113
#
#    electric_car_share  electric_car_count electric_car_share_last_change  \
# 0            0.084375                 108                     2024-09-30
# 1            0.044457                 314                     2024-09-30
# 2            0.062902                 186                     2024-09-30
# 3            0.059941                 142                     2024-09-30
# 4            0.066636                 143                     2024-09-30
#
#    electric_car_charging_spot_count  electric_cars_per_charging_spot  \
# ...

# %%
df.columns
# Out:
# Index(['bfs_nr', 'municipality', 'canton', 'bfs_municipality_type_2012_25',
#        'electric_car_share', 'electric_car_count',
#        'electric_car_share_last_change', 'electric_car_charging_spot_count',
#        'electric_cars_per_charging_spot',
#        'electric_car_charging_spot_last_change', 'solar_potential_usage',
#        'solar_power_installed_kwp', 'solar_potential_usage_last_change',
#        'renewable_heating_share', 'renewable_heating_count',
#        'non_renewable_heating_count', 'no_heating_count',
#        'renewable_heating_share_coverage',
#        'renewable_heating_share_last_change',
#        'elec_consumption_mwh_per_year_per_capita',
#        'elec_consumption_households_mwh_per_year_per_capita',
#        'elec_consumption_mwh_per_year',
#        'elec_consumption_households_mwh_per_year',
#        'elec_consumption_date_from', 'elec_consumption_date_until',
#        'renelec_production_mwh_per_year_per_capita',
# ...

# %%
df_to_save = df[["bfs_nr", "municipality", "elec_consumption_households_mwh_per_year_per_capita", "elec_consumption_households_mwh_per_year", "elec_consumption_mwh_per_year_per_capita", "elec_consumption_mwh_per_year"]]

# %%
df_to_save.head()
# Out:
#    bfs_nr        municipality  \
# 0       1     Aeugst am Albis
# 1       2  Affoltern am Albis
# 2       3          Bonstetten
# 3       4     Hausen am Albis
# 4       5            Hedingen
#
#    elec_consumption_households_mwh_per_year_per_capita  \
# 0                                             2.9119
# 1                                             1.6492
# 2                                             1.7356
# 3                                             2.3004
# 4                                             2.1157
#
#    elec_consumption_households_mwh_per_year  \
# 0                                      5811
# 1                                     21056
# 2                                      9827
# 3                                      9128
# 4                                      8335
#
#    elec_consumption_mwh_per_year_per_capita  elec_consumption_mwh_per_year
# 0                                    4.4623                           8905
# ...
